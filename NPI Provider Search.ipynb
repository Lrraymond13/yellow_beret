# %%
# download physician NPI number from NPPES API
import string
import funcy
import numpy as np
import pandas as pd
import os
import requests
import json
from fuzzywuzzy import fuzz

from dev import APP_DATA_DIR, NAME_COLS
from data_cleaning_functions import remove_punc

NPI_API_URL = 'https://npiregistry.cms.hhs.gov/api/'

# %%
def search(fname, lname, state=None):
    search_params = {'first_name': str(fname),
                    'last_name': str(lname),
                    'country_code': 'US',
                    'pretty': True}
    if state:
        search_params = funcy.merge(search_params, {'state': str(state)})
    r = requests.get(NPI_API_URL, params=search_params)
    if r.status_code==200:
        return r.json()
    print r.status_code
    return

# %%
def check_middle_name(dr_middle_name, json):
    json_middle_name = funcy.get_in(json, ['basic', 'middle_name'], None)
    if not json_middle_name:
        return True
    dr_middle_name = str(dr_middle_name).upper().strip()
    json_middle_name = str(json_middle_name).upper().strip()
    one_letter = (len(dr_middle_name)==1 or len(json_middle_name)==1)
    if one_letter:
        # check first letter of middle names
        return (fuzz.ratio(dr_middle_name[0], json_middle_name[0]) > 95)
    return (fuzz.ratio(dr_middle_name, json_middle_name) > 90)

def clean_cred(cred):
    c2 = remove_punc(cred)
    c3 = c2.split(' ')
    return ''.join(c3)
    
def check_credential(json):
    cred = funcy.get_in(json, ['basic', 'credential'], None)
    if cred:
        creds = cred.split(' ')
        creds = map(clean_cred, creds)
        print creds
        return any(map(lambda x: x in ['MD', 'DDS', 'PHD'], creds))
    return True


def parse_results(results_json, dr_middle_name=None):
    if results_json['result_count'] == 0:
        return (0, None)
    results = results_json['results']
    males = filter(lambda x: x['basic']['gender']=='M', results)
    print len(males)
    mds = filter(check_credential, males)
    print len(mds)
    if dr_middle_name:
        mds = filter(lambda x: check_middle_name(dr_middle_name, x), mds)
    return (len(mds), mds)

# %%
df = pd.read_csv(os.path.join(APP_DATA_DIR, 'fuzzy_all_apps_plus_NIH_info.csv'))

# %%
df.loc[df.clean_first_name=='HOWARD UNIVERSITY COLLEGE OF MEDICINE', 'clean_first_name'] = 'HOWARD'
df.loc[pd.isnull(df.clean_middle_name), 'clean_middle_name'] = 'None'

# %%
npi_res = []
tups = list(df[['person_uuid', 'clean_first_name', 'clean_middle_name', 'clean_last_name']].itertuples())

# %%
for t in tups:
    if pd.isnull(t.clean_first_name):
        continue
    res = search(t.clean_first_name, t.clean_last_name)
    parsed = parse_results(res, t.clean_middle_name)
    npi_res.append((t.person_uuid, ' '.join([t.clean_first_name, t.clean_middle_name, t.clean_last_name]), parsed))
# Out:
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 5
# ['PHD']
# ['MD']
# ['PHD']
# ['LCSW']
# 4
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 9
# ['MD']
# ['CRNA']
# ['MS']
# ['MD', 'FACS']
# ['MD']
# ['MD']
# ['CRNA']
# ['MD']
# ['MD']
# 6
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['DPM']
# ['PHD', '', 'MD']
# ['MS', 'CCCSLP']
# ['PHD', 'CCC', 'SLP']
# ['MD']
# ['MD']
# ['MD']
# ['PHARMACIST']
# 7
# 10
# ['DDS']
# ['MD']
# ['DDS']
# ['MD', 'FAAP']
# ['MD']
# ['MD']
# ['DC']
# ['DDS']
# ['DDS']
# ['MD']
# 9
# 3
# ['PHD', 'MD']
# ['MD']
# ['MD']
# 3
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['MD']
# ['MD']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['COTAL']
# 1
# 2
# ['MD']
# ['MD', 'PHD']
# 2
# 3
# ['CRNA']
# ['MD']
# ['MD']
# 2
# 4
# ['MD']
# ['MD']
# ['MD']
# ['DC']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DMD']
# ['MD']
# 9
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['OD']
# ['MD']
# ['MD']
# 8
# 10
# ['CRNA']
# ['MD']
# ['M', 'D']
# ['DMD']
# ['DDS']
# ['CRNA']
# ['MSSW']
# ['MS', 'LPC']
# ['MD']
# ['LMP']
# 3
# 10
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['PA']
# ['MD']
# ['DO']
# ['MD']
# ['PA', 'C']
# ['MD']
# 7
# 5
# ['MD']
# ['PHD']
# ['MD']
# ['MD']
# ['DMD']
# 4
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['LISW', 'SAP']
# 2
# 5
# ['MD']
# ['MD', 'SAC']
# ['RCP']
# ['MD']
# ['MA', 'LPC']
# 3
# 10
# ['PHD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MACP']
# ['MD']
# ['MD']
# ['MD']
# ['CRNA']
# 8
# 4
# ['MD']
# ['MD']
# ['MD']
# 4
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['OD']
# ['MD']
# 9
# 1
# 1
# 1
# ['MD']
# 1
# 2
# ['PHD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DMD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['O', 'D']
# ['DC']
# 7
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 4
# ['DO']
# ['MD']
# ['DC']
# 2
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 2
# ['MD']
# ['MD']
# 2
# 1
# 1
# 8
# ['MD']
# ['DO']
# ['MD']
# ['DDS']
# ['PT']
# ['OD']
# ['DO']
# ['DO']
# 3
# 10
# ['MD']
# ['MD']
# ['MD']
# ['PH', 'D', 'LPC']
# ['CRNA']
# ['DC']
# ['MD']
# ['MD']
# ['LICSW']
# ['DMD']
# 5
# 2
# ['MD']
# ['DDS']
# 2
# 4
# ['DC']
# ['MD']
# ['LMFT']
# ['PHARM', 'D']
# 1
# 10
# ['MD']
# ['PSYD']
# ['PHARMD', 'DPH']
# ['PAC']
# ['MD']
# ['PHD']
# ['MD']
# ['MD']
# ['M', 'D']
# ['MD']
# 6
# 10
# ['CRNA']
# ['MD']
# ['DO']
# ['RPH']
# ['MDMPH']
# ['MD']
# ['RN']
# ['MD']
# ['DC']
# ['PSYCHIATRIC', 'TECH']
# 3
# 10
# ['DC']
# ['MD']
# ['DDS']
# ['OD']
# ['SA']
# ['DC']
# ['MD']
# ['PA']
# 5
# 10
# ['MD']
# ['MD']
# ['DO']
# ['DO']
# ['MD']
# ['MD', 'PHD']
# ['PAC']
# ['MD']
# ['RPH']
# 6
# 5
# ['DMD']
# ['DC']
# ['LCSW']
# 2
# 10
# ['CRNA']
# ['PT', 'OCS']
# ['DO']
# ['MD', 'PHD']
# ['PA']
# ['MD']
# ['MD']
# ['OD']
# ['MD']
# ['DED']
# 4
# 10
# ['MD', 'PHD']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD', 'FAAP']
# 10
# 1
# ['DO']
# 0
# 4
# ['PSYD', 'DCSW']
# ['MD']
# ['MD']
# ['MD']
# 3
# 9
# ['MD']
# ['MD']
# ['MPT']
# ['MD']
# ['DO']
# ['DPM']
# ['DMD']
# ['RPH']
# 4
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['DO']
# 1
# 1
# ['MD']
# 1
# 2
# ['DDS']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['DDS']
# ['MD']
# ['CRNA']
# ['MD']
# ['MD']
# ['DO']
# ['RPH']
# ['MD']
# ['LCADC']
# ['DMD']
# 5
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['MD']
# ['PAC']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD', 'PH', 'D']
# 1
# 3
# ['MD']
# ['DO']
# 2
# 2
# ['PT']
# ['MD']
# 1
# 3
# ['MD']
# ['MSW', 'LGSW']
# 2
# 1
# ['MD', 'PHD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['OD']
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['OD']
# ['PSYD']
# ['PHD']
# ['MD']
# ['MS']
# 7
# 5
# ['MD']
# ['MD']
# ['MD']
# ['OD']
# ['DMD']
# 3
# 2
# ['MD']
# ['MD']
# 2
# 5
# ['MD']
# ['MD']
# ['DO']
# ['MD']
# ['MD']
# 4
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 3
# ['LICENSED', 'CLINICAL', 'SO']
# ['DDS']
# ['MD']
# 2
# 2
# ['MD']
# ['LCSW']
# 1
# 7
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# 7
# 7
# ['MD']
# ['MD']
# ['PSYD']
# ['DC']
# ['MD']
# ['MD']
# ['RPH']
# 4
# 1
# ['MD']
# 1
# 5
# ['MD']
# ['PNP']
# ['MD']
# ['MD']
# ['MD']
# 4
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['DDS']
# ['DDS']
# ['LCSW']
# ['OD']
# ['DMD']
# ['RPH']
# ['RPH']
# ['APRN', 'FNPC']
# 4
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 3
# ['ARNP']
# ['MD']
# ['RPH']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 3
# ['MD']
# ['PHD']
# ['LCSW']
# 2
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['MD']
# ['DDS']
# 3
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MA']
# 1
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['DDS']
# ['DMD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 3
# ['OD']
# ['MD']
# ['MD']
# 2
# 2
# ['CRNA']
# ['MD']
# 1
# 3
# ['CRNA']
# ['MD']
# 2
# 2
# ['MD']
# ['RPH']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DPT']
# ['MD']
# ['DO']
# ['CRNA', 'ARNP']
# ['MD']
# ['MD']
# ['PHD']
# 7
# 3
# ['PAC']
# ['MD']
# ['MD']
# 2
# 10
# ['MD']
# ['MD']
# ['DPM']
# ['MD']
# ['MD']
# ['MD']
# ['CRNA']
# ['DO']
# ['CRNA']
# 6
# 3
# ['MD']
# ['MD']
# ['LMFT']
# 2
# 2
# ['MD']
# ['MD', 'PHD']
# 2
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DMD']
# ['CFO']
# ['RPH']
# ['ND', 'DC']
# ['PSYD']
# ['MD']
# 5
# 8
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['LCSW']
# ['MD']
# ['MD']
# 7
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['RN']
# 1
# 1
# ['PA']
# 0
# 5
# ['MD', 'PHD']
# ['DO']
# ['MSW', 'LMHP']
# ['DO']
# ['BA', 'LBSW']
# 1
# 9
# ['MD']
# ['MD']
# ['MD']
# ['PHD']
# ['DC']
# ['PA']
# ['DMD']
# ['ATC']
# ['MD']
# 5
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['DDS']
# ['DMD']
# ['MPT']
# ['MD']
# ['MD']
# ['MD']
# 8
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['PSYD']
# ['PHD']
# ['MD']
# ['LCSW']
# ['MD']
# ['MD']
# ['OTMPH']
# 7
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DMD']
# ['MD']
# ['MD']
# ['DDS']
# ['MA', 'MS', 'LMHC']
# ['OTRL']
# 7
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 2
# ['DC']
# ['MD']
# 1
# 3
# ['DO']
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MSW', 'LCSW']
# ['MD']
# ['MD']
# ['DDS']
# ['DO']
# ['MD']
# ['MD']
# ['DO']
# 7
# 4
# ['RPH']
# ['MD']
# ['MD', 'MEM']
# 3
# 5
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['LMT']
# 4
# 5
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# 5
# 10
# ['MD']
# ['MD']
# ['DO']
# ['DMD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# 7
# 10
# ['PHD']
# ['MD']
# ['MD']
# ['LPC']
# ['OD']
# ['PHD']
# ['PT']
# ['DC']
# ['PAC']
# ['MD']
# 5
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD', 'DDS']
# ['PTA']
# ['MD']
# ['MD']
# ['MD']
# ['DPM']
# ['OD']
# ['CRNA']
# ['MD']
# 6
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 10
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['LCSW']
# 1
# 1
# ['MA', 'MFT']
# 0
# 3
# ['DDS']
# ['MD']
# 3
# 3
# ['MD']
# ['MD']
# ['MD']
# 3
# 7
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD', 'MPH']
# ['PTA']
# 6
# 10
# ['MD']
# ['CRNA']
# ['DPM']
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['DC']
# ['LCSW']
# ['MD']
# 5
# 10
# ['OD']
# ['DO']
# ['OD']
# ['PAC']
# ['MD']
# ['DC']
# ['MD']
# ['MD']
# ['DOM']
# 4
# 10
# ['MD']
# ['DDS']
# ['DPM']
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 8
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# 1
# 7
# ['MD']
# ['MD']
# ['MD']
# ['LMSW']
# ['DC']
# ['MD']
# ['CPED']
# 4
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['DMD']
# ['DC']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# ['PHD']
# ['DDS']
# ['DDS']
# ['LICSW']
# ['LMFT']
# 7
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# ['PHD']
# ['DDS']
# ['DDS']
# ['LICSW']
# ['LMFT']
# 7
# 3
# ['MD']
# ['LMSW']
# ['DMD']
# 1
# 5
# ['MD']
# ['MD']
# ['MD']
# 5
# 1
# ['MD']
# 1
# 2
# ['DC']
# ['DMD']
# 0
# 4
# ['DDS']
# ['MD']
# ['MD']
# ['CSW']
# 3
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD', 'PHD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 5
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 5
# 1
# ['MD', 'PHD']
# 1
# 3
# ['MD']
# ['DMD']
# ['RN']
# 1
# 8
# ['MD']
# ['MD']
# ['MD']
# ['DC']
# ['MD']
# ['MD']
# ['RPH']
# ['MD']
# 6
# 8
# ['PHDCBTBCIACEEG']
# ['DO']
# ['DMD']
# ['PHD']
# ['MARVIN', '', 'BERMAN']
# ['DDS']
# ['MDPHD']
# ['MD']
# 3
# 10
# ['DO']
# ['DO']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# ['PSYD']
# ['DO']
# 6
# 3
# ['PHD']
# ['DDS']
# ['MD']
# 3
# 1
# ['MD']
# 1
# 3
# ['RPH']
# ['MD']
# ['MALLP']
# 1
# 1
# ['MD']
# 1
# 3
# ['DPM']
# ['DPM']
# ['MD']
# 1
# 5
# ['MD']
# ['PSYD']
# ['MD']
# ['DDS']
# ['MD']
# 4
# 1
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PHD']
# ['LCSW']
# ['MD']
# ['MD']
# ['MD']
# 9
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PHD']
# ['LCSW']
# ['MD']
# ['MD']
# ['MD']
# 9
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD', 'PHD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 10
# 10
# ['MD']
# ['DC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['CRNA']
# ['OD']
# ['MD']
# ['MD']
# 7
# 10
# ['MD']
# ['LPC']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['OT']
# ['DDS']
# ['MD']
# 8
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 4
# ['MD']
# ['MD']
# ['PHD']
# ['PHARMD']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD', 'PHD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD', 'PHD']
# 1
# 2
# ['DDS', 'PA']
# ['MS', 'LPC', 'CADC']
# 1
# 3
# ['MD']
# ['MD']
# ['DDS']
# 3
# 1
# ['MD']
# 1
# 4
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 4
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DPT']
# ['PT']
# ['MD']
# ['PAC']
# ['DO']
# ['MD']
# ['DMD']
# 5
# 4
# ['DDS', 'MS']
# ['OD']
# ['MD']
# ['MD']
# 3
# 1
# ['MD']
# 1
# 9
# ['MD']
# ['MD']
# ['DO']
# ['OD']
# ['MD']
# ['MD']
# ['DMD', 'MPH']
# ['DMD']
# ['DDS']
# 5
# 10
# ['MD']
# ['MD']
# ['ATC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['OD']
# 8
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 7
# ['MD']
# ['MD']
# ['PT']
# ['MD']
# ['LCSW']
# ['MD']
# ['MD']
# 5
# 1
# ['MD']
# 1
# 5
# ['DPM']
# ['MD']
# ['PSYD']
# ['DDS']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 5
# ['MD']
# ['DPM']
# ['MD']
# ['L', 'AC']
# 3
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 4
# ['DO']
# ['MD']
# ['DDS']
# ['DC']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD', 'MSE']
# ['PAC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DC']
# ['PHD']
# 8
# 9
# ['DO']
# ['MD']
# ['MD']
# ['OD']
# ['MD']
# ['DC', 'PHD']
# ['MD']
# ['ANPC']
# ['MD']
# 6
# 5
# ['MD']
# ['MD']
# ['CRNA']
# ['DO']
# ['MD']
# 3
# 3
# ['MD']
# ['DC']
# ['MA', 'LCPC']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['PHD']
# ['MD']
# 2
# 2
# ['MD']
# ['MD']
# 2
# 0
# 0
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 3
# ['MD']
# ['MD']
# ['MD']
# 3
# 2
# ['DC']
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 4
# ['MD']
# ['PAC']
# ['DDS']
# ['DMD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 5
# ['DO']
# ['DMD']
# ['L', 'C', 'P', 'C']
# ['PA']
# ['LICDC']
# 0
# 3
# ['MD']
# ['ARRTR', 'EMTB']
# ['M', 'D']
# 1
# 5
# ['MD']
# ['CRNA']
# ['MSW', 'LCSW']
# ['MA', 'MSW', 'LMSW', 'DCSW']
# ['MD']
# 2
# 2
# ['MD']
# ['MD']
# 2
# 10
# ['MD']
# ['MD']
# ['DO']
# ['PA']
# ['LCSW']
# ['MD']
# ['DPM']
# ['DMD']
# ['MD']
# 5
# 7
# ['RPAC']
# ['PT']
# ['MD']
# ['MD']
# ['DC']
# ['LMFT']
# ['CSTCSFA']
# 2
# 9
# ['DDS']
# ['PAC']
# ['MD']
# ['DMD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['RPH']
# 6
# 5
# ['MD']
# ['DDS', 'PA']
# ['DC']
# ['PT']
# ['DDS']
# 3
# 2
# ['PHD']
# ['MD']
# 2
# 3
# ['MD']
# ['MA']
# ['MD']
# 2
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 2
# ['DDS']
# ['MD']
# 2
# 4
# ['MD']
# ['DMD']
# ['PHD']
# ['MD']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# 2
# 9
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DMD']
# ['LMT']
# 7
# 3
# ['MD']
# ['DDS']
# ['MD']
# 3
# 1
# ['MD', 'MPH']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 3
# ['DO']
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 4
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# 4
# 3
# ['MD']
# ['MD']
# ['MD']
# 3
# 3
# ['MD']
# ['MD']
# ['DC']
# 2
# 10
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['MSW']
# ['MD']
# ['DMD']
# ['MD']
# ['MD']
# ['MA', 'CCCSLP']
# 6
# 9
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 9
# 7
# ['MD']
# ['DC']
# ['MD']
# ['LIC', 'AC']
# ['OTRL']
# 4
# 10
# ['DO']
# ['DDS']
# ['DC']
# ['MD']
# ['MD']
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['DC']
# 6
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PA', '', 'C']
# ['MD']
# 9
# 9
# ['OD']
# ['MD']
# ['OD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PT']
# 6
# 10
# ['MD']
# ['PH', 'D']
# ['DPT']
# ['MD']
# ['MD']
# ['MD']
# ['DPM']
# ['MD']
# ['MD']
# ['MD']
# 7
# 10
# ['MD']
# ['MD', 'PA']
# ['MD']
# ['MD', 'MPH', 'FACP']
# ['MD']
# ['MD']
# ['DPM']
# ['MD']
# ['MD']
# ['LCSW', 'LPC']
# 8
# 10
# ['MD']
# ['MD', 'PA']
# ['MD']
# ['MD', 'MPH', 'FACP']
# ['MD']
# ['MD']
# ['DPM']
# ['MD']
# ['MD']
# ['LCSW', 'LPC']
# 8
# 10
# ['MD']
# ['MD', 'PA']
# ['MD']
# ['MD', 'MPH', 'FACP']
# ['MD']
# ['MD']
# ['DPM']
# ['MD']
# ['MD']
# ['LCSW', 'LPC']
# 8
# 10
# ['MD']
# ['DPM']
# ['MD', 'MED']
# ['MD']
# ['MD', 'DPM']
# ['MD']
# ['MD']
# ['PHD']
# ['MD']
# ['CRNA']
# 8
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DMD']
# 9
# 5
# ['MD']
# ['MED', 'CASS']
# ['MD']
# ['MSW', 'LCSW']
# ['LPCA']
# 2
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# ['DC']
# ['DDS']
# ['PA']
# ['CRNA']
# ['MD']
# ['MD']
# 6
# 2
# ['MD']
# ['DMD']
# 1
# 10
# ['DC']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['DDS']
# ['RPH']
# 8
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['ACSW', 'LCSW']
# ['MD']
# 9
# 9
# ['MD']
# ['PA']
# ['MD']
# ['MD']
# ['MD']
# ['RPH']
# ['PT']
# ['DDS']
# 6
# 10
# ['DPM']
# ['DPM']
# ['DO']
# ['DO']
# ['CRNA']
# ['MD']
# ['MD']
# ['CRNA']
# ['OD']
# ['MD']
# 3
# 10
# ['MD']
# ['MD', 'PHD']
# ['MD']
# ['MD']
# ['MD']
# ['DC']
# ['MD']
# ['MD']
# ['MSW', 'LCSW']
# ['MD']
# 8
# 10
# ['MD']
# ['MD', 'PHD']
# ['MD']
# ['MD']
# ['MD']
# ['DC']
# ['MD']
# ['MD']
# ['MSW', 'LCSW']
# ['MD']
# 8
# 10
# ['MD']
# ['MD', 'PHD']
# ['MD']
# ['MD']
# ['MD']
# ['DC']
# ['MD']
# ['MD']
# ['MSW', 'LCSW']
# ['MD']
# 8
# 10
# ['LISWCP', 'DCSW', 'BCD']
# ['AUD']
# ['MD']
# ['MD']
# ['MD']
# ['DC']
# ['DO']
# ['DC']
# ['MD']
# ['MD']
# 5
# 10
# ['MD']
# ['MD']
# ['MD']
# ['PT']
# ['PHD']
# ['CRNA']
# ['LCSW']
# ['DDS']
# ['MD']
# ['LMSW']
# 6
# 10
# ['MD']
# ['MD']
# ['LCSW']
# ['MD']
# ['MD']
# ['DPM']
# ['AUD']
# ['DC']
# ['MD']
# ['MD']
# 6
# 8
# ['MD']
# ['PA']
# ['MD']
# ['ARNP']
# ['DDS']
# ['MD']
# 6
# 5
# ['MD']
# ['MD']
# ['MD']
# ['PH', 'D']
# ['RPH']
# 3
# 3
# ['MD']
# ['MD']
# ['LPN']
# 2
# 1
# ['MD']
# 1
# 3
# ['DO']
# ['RPH']
# ['LMSW']
# 0
# 10
# ['MD']
# ['MD']
# ['PT']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# 9
# 2
# ['MD']
# ['MD']
# 2
# 10
# ['ACSW', 'LCSW']
# ['PAC']
# ['MD']
# ['DMD']
# ['MD']
# ['MD']
# ['MD']
# ['DC']
# ['DDS']
# ['PAC']
# 5
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD', 'DC']
# ['DDS']
# ['DDS']
# ['MD']
# ['DO']
# ['DDS']
# ['PT']
# ['LCSW', 'CSOTP']
# 7
# 4
# ['MD']
# ['MD']
# ['ARNP']
# ['DDS']
# 3
# 1
# ['MD']
# 1
# 1
# 1
# 1
# ['CPRSS']
# 0
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['CRNA']
# 0
# 7
# ['DDS']
# ['PT']
# ['DC']
# ['MD']
# ['MD', 'RETIRED']
# ['MD']
# 5
# 3
# ['MD']
# ['MD']
# ['MD']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 8
# ['MD']
# ['MD']
# ['PT']
# ['MA', 'LPC']
# ['MD']
# ['MD']
# ['DDS']
# ['ATC']
# 5
# 5
# ['MD']
# ['MD']
# ['LPC']
# ['MD']
# ['MFT']
# 3
# 3
# ['CRNA']
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['LADCLCPCCCS']
# 0
# 10
# ['PAC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PAC']
# ['MD']
# ['MD']
# ['MD']
# 8
# 10
# ['MD']
# ['PHD']
# ['MD']
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['DPM']
# ['MD']
# ['DO']
# 7
# 2
# ['MD']
# ['DDS']
# 2
# 1
# ['M', 'D']
# 0
# 1
# ['MD']
# 1
# 8
# ['MD']
# ['DC']
# ['MD']
# ['PAC']
# ['DDS']
# ['IDC']
# ['MD']
# 5
# 10
# ['MD']
# ['DMD']
# ['MD']
# ['MD']
# ['DDS', 'MS']
# ['MD']
# ['DPT']
# ['MD']
# ['MD']
# ['MD']
# 8
# 6
# ['MD']
# ['DC']
# ['MD']
# ['MD']
# ['DC']
# 4
# 9
# ['MD']
# ['MD']
# ['DMD']
# ['MD']
# ['DDS']
# ['LCSW']
# ['MPAC']
# ['PT']
# ['RN', 'CRNA']
# 4
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 9
# ['MD']
# ['OD']
# ['LPC']
# ['MD']
# ['MD']
# ['MD']
# ['DC']
# ['SLPCCC']
# ['MD']
# 5
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['PAC']
# ['MD']
# ['PCC']
# ['MD']
# ['CRNA']
# ['LCSW']
# ['DMD']
# ['LMSW']
# 4
# 10
# ['MD']
# ['MD']
# ['MD']
# ['LCSW']
# ['PA']
# ['MD']
# ['LCSW']
# ['OD']
# ['OD']
# ['RPH']
# 4
# 2
# ['MD']
# ['PHD', 'MP']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 8
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['PHARMD']
# ['RT']
# 6
# 2
# ['MD']
# ['MD']
# 2
# 4
# ['C', 'O']
# ['M', 'D']
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 9
# ['OD']
# ['MD']
# ['MD']
# ['MD']
# ['OD']
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# 6
# 1
# ['MD']
# 1
# 1
# ['APRNBC']
# 0
# 1
# ['MD']
# 1
# 3
# ['OD']
# ['MD']
# ['MD']
# 2
# 2
# ['MD']
# ['MD']
# 2
# 3
# ['DDS', 'MPH', 'MAGD']
# ['MD']
# ['MD']
# 3
# 1
# ['MD']
# 1
# 5
# ['MD']
# ['MD']
# ['DDS']
# ['DC']
# ['DDS']
# 4
# 5
# ['DDS']
# ['MD']
# ['DDS']
# ['MD']
# ['DDS']
# 5
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['AUD']
# ['MD']
# ['MD']
# ['MD']
# ['OD']
# ['DO']
# ['PAC']
# ['CRNA']
# 5
# 10
# ['MD', 'MS']
# ['MD']
# ['DO']
# ['MD']
# ['MD']
# ['DC', 'PHD']
# ['DC']
# ['DMD']
# ['DO']
# ['PHD']
# 6
# 1
# ['MD']
# 1
# 1
# ['RN']
# 0
# 7
# ['MD']
# ['DPM']
# ['MD']
# ['MD']
# ['MD']
# ['NP']
# ['MD']
# 5
# 7
# ['DO']
# ['OD']
# ['MD']
# ['DDS']
# ['DDS']
# ['DDS', 'MS', 'PC']
# ['CRNA']
# 4
# 5
# ['DR']
# ['MD']
# ['CRNA', 'APN']
# ['OPTICIAN']
# ['PHD']
# 2
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['GENERAL', 'DENTIST']
# ['MSW']
# ['DMD']
# ['MD']
# ['MD']
# 7
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 4
# ['MD']
# ['OD']
# ['DC']
# ['PHD']
# 2
# 9
# ['MD']
# ['DC']
# ['PHD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['CRNA']
# ['MD']
# 7
# 10
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DR']
# 9
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['MD']
# ['MD']
# 3
# 2
# ['D', 'MD']
# ['MD']
# 2
# 7
# ['ATC']
# ['DO']
# ['MD']
# ['DDS']
# ['MD']
# ['DC']
# 4
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 3
# ['DC']
# ['MD']
# ['MD']
# 2
# 4
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 7
# ['MD']
# ['MD']
# ['MD']
# ['MASTERS', 'DEGREE']
# ['DPT']
# 5
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 9
# 10
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['RPT']
# 8
# 3
# ['MD']
# ['PHD']
# ['PT']
# 2
# 1
# ['MD']
# 1
# 4
# ['MD']
# ['MD']
# 4
# 3
# ['MD']
# ['MD']
# ['DO']
# 2
# 3
# ['MD', 'FACOEM']
# ['PHD']
# ['DDS']
# 3
# 3
# ['MD']
# ['PHARMD']
# ['LBSW', 'CADCM']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 9
# ['MD']
# ['DDS']
# ['DDS']
# ['OD']
# ['ROM']
# ['MD']
# ['MD']
# 7
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 5
# ['MD']
# ['DC']
# ['OD']
# ['PT']
# ['MD']
# 2
# 3
# ['PSYD']
# ['MD']
# ['MD']
# 2
# 2
# ['MD']
# ['DMD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 5
# ['MD']
# ['DO']
# ['SLP']
# ['LMBT']
# ['DDS']
# 2
# 2
# ['MD']
# ['MD']
# 2
# 3
# ['DPM']
# ['MD']
# ['DDS', 'MPH']
# 2
# 9
# ['MD']
# ['DMD']
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['DC']
# ['OD']
# ['CRNA']
# 4
# 10
# ['MD']
# ['MD']
# ['OD']
# ['PA']
# ['MD']
# ['MD']
# ['MD']
# ['OD']
# ['PAC']
# ['MD']
# 6
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# ['MD']
# ['MD']
# ['DC']
# 8
# 10
# ['MD']
# ['MD']
# ['PAC']
# ['MD']
# ['OD']
# ['PA']
# ['RN', 'ARNP', 'CRNA']
# ['MD']
# ['MD']
# ['MD']
# 6
# 10
# ['MD']
# ['MD']
# ['MD', 'PHD']
# ['MD']
# ['MD']
# ['PAC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 9
# 10
# ['MD']
# ['MD']
# ['MD', 'PHD']
# ['MD']
# ['MD']
# ['PAC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 9
# 10
# ['MD']
# ['MD']
# ['MD', 'PHD']
# ['MD']
# ['MD']
# ['PAC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 9
# 10
# ['MD']
# ['DPM']
# ['MD']
# ['MD']
# ['MD']
# ['NP']
# ['MD']
# ['MD']
# ['MD']
# 8
# 1
# ['MD']
# 1
# 0
# 0
# 3
# ['PAC']
# ['MD']
# ['ANPBC']
# 1
# 4
# ['MD']
# ['MD']
# ['MD']
# ['LMP']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 4
# ['MD']
# ['MD']
# ['MD']
# ['PHD', 'MFT']
# 4
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['OD']
# 2
# 10
# ['OD']
# ['OD']
# ['MD']
# ['MD']
# ['MD']
# ['PHD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 8
# 5
# ['MD']
# ['PHD']
# ['DDS']
# ['MD']
# ['MD']
# 5
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['LMFT']
# ['PHD']
# ['MD']
# ['DPM']
# ['MD']
# 8
# 10
# ['DPM']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['LCSW']
# 8
# 8
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['LCSW']
# ['PHD']
# 7
# 10
# ['DDS']
# ['MD']
# ['MD']
# ['M', 'D']
# ['DDS']
# ['MD']
# ['MD']
# ['DC']
# ['MD', 'PHD']
# ['DMD']
# 7
# 10
# ['DDS']
# ['MD']
# ['MD']
# ['M', 'D']
# ['DDS']
# ['MD']
# ['MD']
# ['DC']
# ['MD', 'PHD']
# ['DMD']
# 7
# 10
# ['MD']
# ['MD']
# ['MD']
# ['OD']
# ['RPH']
# ['MD']
# ['MD']
# ['OD']
# ['DO']
# ['MD']
# 6
# 9
# ['MD']
# ['MD']
# ['OD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 8
# 10
# ['MD']
# ['MD']
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MPT']
# ['DDS']
# ['MD']
# 8
# 10
# ['MD']
# ['DMD']
# ['MD']
# ['MD']
# ['MD']
# ['DPM']
# ['DO']
# ['MD']
# ['MD']
# ['DPM']
# 6
# 2
# ['DO']
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MDFACS']
# ['MD']
# ['PHARMD', 'PH', 'D', 'RPH']
# ['MD']
# ['MD']
# ['MD']
# 8
# 10
# ['MD']
# ['MD']
# ['PHARMD', 'BCPP']
# ['MD']
# ['DO']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# 8
# 10
# ['MD']
# ['MD']
# ['PHARMD', 'BCPP']
# ['MD']
# ['DO']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# 8
# 10
# ['MD']
# ['DC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PHD']
# ['PHD']
# 9
# 8
# ['MD']
# ['MD', 'MHSA']
# ['MD']
# ['DDS']
# ['DC']
# ['ATC']
# ['MD']
# ['ND']
# 5
# 10
# ['MD']
# ['OD']
# ['PAC']
# ['MD']
# ['DO', 'PA']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 7
# 10
# ['MD']
# ['OD']
# ['PAC']
# ['MD']
# ['DO', 'PA']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 7
# 10
# ['MD']
# ['DO']
# ['DPM']
# ['MD']
# ['MD']
# ['DO']
# ['MD']
# ['M', 'D']
# ['DPM']
# 5
# 10
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['DPM']
# ['DO']
# ['PHD']
# ['MD']
# ['MD']
# ['DO']
# 7
# 10
# ['MD']
# ['DPM']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['DOPA']
# ['MD', 'FAAP']
# 8
# 10
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PHD']
# ['DDS']
# ['MD']
# ['PA']
# ['MD']
# 9
# 10
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PHD']
# ['DDS']
# ['MD']
# ['PA']
# ['MD']
# 9
# 10
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PHD']
# ['DDS']
# ['MD']
# ['PA']
# ['MD']
# 9
# 1
# ['MD']
# 1
# 4
# ['MD']
# ['MD']
# ['MD']
# ['DPM']
# 3
# 1
# ['MD']
# 1
# 6
# ['MD']
# ['MD']
# ['MD']
# ['MFT']
# ['MD']
# ['MD']
# 5
# 1
# ['MD']
# 1
# 1
# ['CADC']
# 0
# 1
# ['MD']
# 1
# 10
# ['ATC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MSW']
# ['MD']
# ['PT']
# 7
# 10
# ['MD']
# ['DO']
# ['MD']
# ['DC']
# ['MD']
# ['MD']
# ['MD']
# ['PHD']
# ['DO']
# ['RPH']
# 6
# 9
# ['IDC']
# ['MD']
# ['MD']
# ['PAC']
# ['DDS']
# ['MD']
# ['DMD']
# ['MA']
# ['RD', 'LD']
# 4
# 3
# ['MD']
# ['MD']
# ['DPT']
# 2
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['DPM']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['PTA']
# ['MD']
# 8
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# ['MD']
# ['MD']
# ['DDS', 'MS']
# ['PT']
# ['MD']
# ['MD']
# 8
# 10
# ['MD']
# ['MD']
# ['HEALTH', 'SERVICES', 'TECH']
# ['MD']
# ['PA']
# ['MD']
# ['DC']
# ['MD']
# ['MD']
# 7
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 2
# ['DC']
# ['DDS']
# 1
# 2
# ['MD']
# 2
# 1
# ['MD']
# 1
# 6
# ['MD']
# ['MD']
# ['LISW']
# ['DDS']
# ['MD']
# 5
# 1
# ['PHYSICAL', 'THERAPIST']
# 0
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['DDS']
# 2
# 1
# ['MD']
# 1
# 5
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 5
# 10
# ['DDS']
# ['MD', 'MPH']
# ['MD']
# ['DC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 9
# 10
# ['CRNA']
# ['DC']
# ['PAC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 7
# 10
# ['CRNA']
# ['DC']
# ['PAC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 7
# 10
# ['MD']
# ['PSYD']
# ['PSYD', 'HSPP']
# ['OD']
# ['DC']
# ['MD']
# ['DC']
# ['DC']
# ['MD']
# ['DDS']
# 4
# 9
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['LMT']
# ['DO']
# ['DPH']
# 6
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DPM', 'INC']
# ['MD']
# 9
# 3
# ['MD']
# ['PT']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['LPC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PT']
# ['DO']
# ['DDS']
# ['MD']
# ['MA']
# 6
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# 1
# 3
# ['MD']
# ['LICSW']
# ['BS']
# 1
# 1
# ['MD']
# 1
# 9
# ['MD']
# ['MD']
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['LSW', '', 'LADC', 'I', 'CADAC', 'II']
# 7
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['MD']
# ['MSW']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['PHD']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['PAC']
# ['DDS']
# 9
# 10
# ['MD']
# ['MD']
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# ['LMFT', 'CASAC']
# ['LPCC']
# ['DO']
# 5
# 5
# ['MD']
# ['MD']
# ['MD']
# ['PHD']
# 5
# 8
# ['MD']
# ['DDS', 'MD']
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# ['MD']
# ['LPC']
# 6
# 3
# ['MD']
# ['DC']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 0
# 0
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['RPH', 'CPH']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# 9
# 8
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# ['MD']
# ['DDS']
# ['FNP']
# 6
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['CRNA']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['CASAC']
# 1
# 1
# ['MD']
# 1
# 8
# ['OD']
# ['DDS']
# ['MD']
# ['PHD']
# ['MD']
# ['LMT']
# ['MD']
# ['LAC', 'LMT']
# 5
# 1
# ['MD']
# 1
# 4
# ['MD']
# ['MD']
# ['DMD']
# ['PAC']
# 2
# 3
# ['MD']
# ['DO']
# ['MD']
# 2
# 8
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PHARMD']
# ['LCPC']
# ['MD']
# 5
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 4
# ['MD']
# ['MD']
# ['MD']
# ['DC']
# 3
# 0
# 0
# 1
# ['FMP', 'PAC']
# 0
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['LD']
# ['MD']
# ['PHD']
# ['DDS']
# ['DO']
# ['MD']
# ['DPT']
# ['DC']
# 6
# 2
# ['MD']
# ['DDS']
# 2
# 2
# ['DO']
# ['MD']
# 1
# 1
# ['PHD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['RPH']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DC']
# ['MD']
# 8
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['OD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['LCSW']
# ['MD']
# ['PA']
# ['PT']
# 6
# 10
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# ['LMSW']
# 8
# 2
# ['MD', 'PHD']
# ['MD']
# 2
# 2
# ['DPM']
# ['LPC']
# 0
# 1
# 1
# 10
# ['PA']
# ['DC']
# ['MD']
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['DC']
# ['MD']
# ['MD']
# 6
# 10
# ['MD']
# ['PHARMACIST']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# 9
# 10
# ['MFTI']
# ['MD']
# ['FNP']
# ['MD']
# ['MD']
# ['MD']
# ['OD']
# ['DDS']
# ['DDS']
# ['MD']
# 7
# 10
# ['MFTI']
# ['MD']
# ['FNP']
# ['MD']
# ['MD']
# ['MD']
# ['OD']
# ['DDS']
# ['DDS']
# ['MD']
# 7
# 10
# ['MD']
# ['LMHC']
# ['ATC', 'CSCS']
# ['MD']
# ['PHARMD']
# ['PHARMD']
# ['DPT']
# ['MD']
# ['PT', 'DPT']
# 4
# 10
# ['PHD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MFT']
# ['PHARMACIST']
# 8
# 10
# ['MD']
# ['MD']
# ['OD']
# ['DO']
# ['DC']
# ['MD']
# 7
# 0
# 0
# 10
# ['PAC']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 9
# 10
# ['DC']
# ['MD']
# ['PAC']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['MSW']
# ['RN', 'FNP']
# ['MD']
# 6
# 10
# ['MS']
# ['MD']
# ['DDS']
# ['MD']
# ['DDS']
# ['MD']
# ['PHDBCBAD']
# ['MD']
# ['MD']
# ['MD']
# 8
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['PAC']
# ['DC']
# ['OD']
# ['RPH']
# ['MD']
# 6
# 2
# ['PHARMACIST']
# ['MD']
# 1
# 10
# ['RNCSFNPC']
# ['MD']
# ['MD']
# ['ME']
# ['MD']
# ['MD']
# ['CHIROPRACTOR']
# ['DO']
# ['MD']
# ['PAC']
# 5
# 3
# ['MD']
# ['MD']
# ['PHD']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['DO']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 4
# ['MD']
# ['MD']
# ['DMD']
# ['OTAL']
# 2
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 3
# ['DDS']
# ['DO']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD', 'P', 'C']
# ['MD']
# ['MD']
# ['DC']
# ['DO']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# 8
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD', 'JD']
# 1
# 1
# ['MD']
# 1
# 8
# ['PHD']
# ['PAC']
# ['MD']
# ['DDS']
# ['LCSW']
# ['LIC', 'AC']
# ['MD']
# ['RPH']
# 4
# 1
# ['MD']
# 1
# 6
# ['MD']
# ['LPC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 5
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 8
# ['MD']
# ['OD']
# ['OD']
# ['CSTFA']
# ['MD']
# ['LCSW', 'LCDCS']
# 4
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 5
# ['MD']
# ['OD']
# ['PA']
# ['DC']
# ['LMFT']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 0
# 0
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 4
# ['MD']
# ['PA']
# ['DDS']
# ['LPC']
# 2
# 2
# ['PHD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['MD']
# ['MD']
# 3
# 3
# ['DDS']
# ['MD']
# ['LCSW']
# 2
# 10
# ['MD']
# ['MD', 'MPH']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# ['OD']
# ['MD']
# 9
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['AA']
# ['DC', 'MPS', 'MED']
# 1
# 1
# ['MD']
# 1
# 4
# ['MD']
# ['MD']
# 4
# 3
# ['MD']
# ['MD']
# 3
# 2
# ['MD']
# 2
# 2
# ['PSYD']
# ['MD']
# 1
# 1
# ['MD', 'SM']
# 1
# 5
# ['CRNA']
# ['MD']
# ['MD']
# ['MD']
# ['PT', 'DPT']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 5
# ['MD']
# ['PHD']
# ['MD']
# ['MD']
# ['MD']
# 5
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD', 'PHD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MDFACC']
# ['MD', 'MPH']
# 1
# 3
# ['MD']
# ['MD']
# 3
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 7
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# ['RN']
# 6
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 4
# ['MD']
# ['MD']
# ['MD']
# 4
# 1
# ['MD']
# 1
# 1
# ['MD', 'PHD']
# 1
# 1
# ['MD']
# 1
# 1
# ['DDS']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['DPM']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['LAC']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 8
# ['ATC', 'CSCS']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PA']
# ['BA']
# 5
# 2
# ['MD']
# ['MD']
# 2
# 4
# ['MD']
# ['DDS']
# ['MD']
# ['LMSW']
# 3
# 1
# ['M', 'D']
# 0
# 3
# ['DC']
# ['MD']
# ['PSYD']
# 1
# 2
# ['LICSW']
# ['MD']
# 1
# 1
# ['LCSWR', 'BCD']
# 0
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PHD']
# ['MD']
# ['MD']
# ['MA', 'LMFT']
# 9
# 4
# ['MD']
# ['MD']
# ['DDS']
# ['PHD']
# 4
# 10
# ['MD']
# ['MD']
# ['CRNA']
# ['MD']
# ['DMDFAGD']
# ['MD']
# ['DMD']
# ['MD']
# ['RPH']
# ['MFT']
# 5
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DC']
# ['MD']
# ['PHD']
# ['MD']
# ['MFT']
# ['MD']
# 8
# 10
# ['DPM']
# ['MD']
# ['DPM']
# ['MD', 'FACS']
# ['MD', 'FACC']
# ['DDS']
# ['MD']
# 8
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# ['OD']
# ['DC']
# ['MD']
# ['DDS']
# 7
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# ['OD']
# ['DC']
# ['MD']
# ['DDS']
# 7
# 3
# ['MD']
# ['MD']
# ['MD']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 10
# ['M', 'D']
# ['PT']
# ['CADC', 'CPADAC']
# ['MD']
# ['PTA']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 6
# 4
# ['MD']
# ['MD']
# ['DC']
# 3
# 10
# ['MD']
# ['DO']
# ['LAT', 'ATC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 8
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['DO']
# ['DDS']
# ['MD']
# ['MD']
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# 8
# 1
# ['RN']
# 0
# 2
# ['MD']
# ['MD']
# 2
# 2
# ['MD']
# ['PHARM', 'D']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 4
# ['MD']
# ['DC']
# ['MD']
# ['RPH']
# 2
# 2
# ['MD']
# ['MD']
# 2
# 2
# ['MD']
# ['DDS']
# 2
# 3
# ['MD']
# ['DMD']
# 2
# 5
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MA']
# 4
# 1
# ['MD']
# 1
# 4
# ['MD']
# ['PHD']
# ['MD']
# 4
# 6
# ['MD']
# ['MD']
# ['PAC']
# ['MD']
# ['DO']
# ['DC']
# 3
# 1
# ['MD']
# 1
# 6
# ['MD']
# ['MD']
# ['MD']
# ['PAC']
# ['ATC']
# 4
# 1
# ['MD']
# 1
# 1
# ['MD', '', 'PHD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['MD']
# 3
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['MD']
# ['PT']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['DMD']
# 0
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['RPH']
# ['LCSW']
# ['PH', 'D']
# ['DDS']
# ['DDS']
# 7
# 2
# ['MD']
# ['MD']
# 2
# 2
# ['MD']
# ['MD']
# 2
# 2
# ['MD']
# ['DMD', 'PA']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['M', 'D']
# ['MD']
# ['MD']
# ['DPM']
# ['MD']
# ['MD']
# ['DDS']
# 8
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['RPH']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DPM']
# ['MD']
# ['EDD', 'LPC', 'LMFTA']
# ['MD']
# ['MD']
# 8
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['MD']
# ['MD']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 7
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# ['DDS']
# ['MD']
# 6
# 5
# ['MD']
# ['MD']
# ['CNS']
# ['BS']
# ['BS', '', 'LAT']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 3
# ['MD', 'PHD']
# ['MD']
# ['CMT']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 5
# ['MD']
# ['MD']
# ['DDS']
# ['PT']
# ['PHD']
# 4
# 9
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['DO']
# ['MD']
# 8
# 1
# ['MD']
# 1
# 0
# 0
# 1
# ['PSYD']
# 0
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 6
# ['DO']
# ['MD']
# ['DDS']
# ['MD']
# ['OD']
# 4
# 5
# ['PT']
# ['MD']
# ['MD']
# ['MD']
# 4
# 7
# ['DO']
# ['DO']
# ['DDS']
# ['MD', 'FACEP']
# ['PHD']
# ['MD']
# ['MD']
# 5
# 2
# ['PHD']
# ['MD', 'PHD']
# 2
# 10
# ['DDS']
# ['DO']
# ['OD', 'PC']
# ['PSYD']
# ['MD']
# ['DC']
# ['DMD']
# ['DDS']
# ['DMD']
# ['DC']
# 3
# 10
# ['DPM']
# ['MD']
# ['PA']
# ['MD']
# ['MD']
# ['MD']
# ['M', 'D']
# ['MD']
# ['MD']
# ['DDS']
# 7
# 9
# ['DMD']
# ['PT']
# ['DC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['RPH']
# 5
# 10
# ['MD']
# ['MD']
# ['CNP']
# ['PHARMD']
# ['MD']
# ['LICSW']
# ['DDS']
# ['PT']
# ['MD']
# ['PHARMD']
# 5
# 2
# ['MD']
# ['MD']
# 2
# 10
# ['DDS']
# ['DDS', 'MS']
# ['DO']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['DO']
# ['MD']
# ['MD']
# 8
# 10
# ['DC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['RPH']
# ['MD']
# ['DO']
# ['MD']
# 7
# 10
# ['DC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['RPH']
# ['MD']
# ['DO']
# ['MD']
# 7
# 3
# ['MD']
# ['MD']
# ['LMT']
# 2
# 2
# ['MD']
# ['PHD']
# 2
# 7
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DPM']
# 6
# 1
# ['MD', 'PHD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# 1
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 5
# ['DO']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# 4
# 3
# ['MD']
# ['MD']
# ['PAC']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['MD']
# ['DDS']
# 3
# 2
# ['OD']
# ['MD']
# 1
# 0
# 0
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 4
# ['OD']
# ['MD']
# ['PHD']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['DO']
# ['PA']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['OD']
# ['MD']
# 7
# 10
# ['DO']
# ['PT']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DPM']
# ['MD']
# ['PA']
# ['MD']
# 6
# 1
# ['L', 'AC']
# 0
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['OD']
# ['MD']
# 1
# 1
# ['MD']
# 1
# 9
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DC']
# ['PAC']
# 7
# 3
# ['MD']
# ['MD']
# ['MD', 'PHD']
# 3
# 10
# ['MD']
# ['DPM']
# ['MD']
# ['DC']
# ['MD']
# ['DDS']
# ['CRNA']
# ['DC']
# ['PHD']
# ['MD']
# 6
# 2
# ['MD']
# ['MD']
# 2
# 2
# ['MD']
# ['PHD']
# 2
# 2
# ['MD', 'PHD']
# ['MD']
# 2
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DMD']
# ['DMD']
# ['MD']
# ['RPH']
# ['MD']
# ['DMD']
# ['PAC']
# 5
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PHD']
# ['OD']
# ['MD']
# ['MD']
# ['MD']
# ['PT']
# 8
# 1
# ['MD']
# 1
# 9
# ['MD']
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['ND']
# ['MPAS', 'PAC']
# 6
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PHD']
# ['PHD']
# ['LSCWC']
# ['MDFACPFCP']
# 7
# 5
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['LMFT']
# 4
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 6
# ['MD']
# ['MD']
# ['PAC']
# ['MD']
# ['BA', 'PSYCHOLOGY']
# ['DO']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['DMD']
# ['MD']
# 1
# 1
# ['MD']
# 1
# 5
# ['MD']
# ['DO']
# ['MD']
# ['DDS', 'MS']
# ['MD']
# 4
# 0
# 0
# 8
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['DO']
# ['PAC']
# 6
# 10
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# ['MSW', 'PHD']
# ['DDS']
# ['DMD']
# ['MD']
# ['MD']
# 9
# 10
# ['MD']
# ['DMD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# 9
# 1
# 1
# 3
# ['MD']
# ['DC']
# ['MD']
# 2
# 1
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['MD']
# ['DDS']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['OD']
# ['RPH']
# ['PHD']
# ['MD']
# ['MFT']
# ['CMP']
# ['THOMAS', 'N', 'FULLER']
# ['MD']
# 5
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['PSY', 'D']
# ['RN', 'C', '', 'LPC']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD', 'PHD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 5
# ['BSN', 'RN']
# ['RPH']
# ['MD']
# 3
# 5
# ['MD']
# ['MD']
# ['MD']
# ['MA', 'LPC']
# 4
# 10
# ['MD']
# ['LCSW']
# ['DDS', 'MS']
# ['MD']
# ['MD']
# ['DC']
# ['RPH']
# ['PAC']
# ['PH', 'D']
# ['ATC']
# 4
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['MD']
# ['LCSW']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['ABOCNCLCACCOA']
# ['DPM']
# ['DPM']
# ['MD']
# ['MD']
# ['RPH']
# ['MD']
# ['DDS']
# ['MD']
# 6
# 10
# ['ABOCNCLCACCOA']
# ['DPM']
# ['DPM']
# ['MD']
# ['MD']
# ['RPH']
# ['MD']
# ['DDS']
# ['MD']
# 6
# 8
# ['DC']
# ['RPAC']
# ['DDS']
# ['LPN']
# ['DDS']
# ['MD']
# 5
# 10
# ['DC']
# ['MD']
# ['MD']
# ['PAC']
# ['RPH']
# ['DDS']
# ['DDS', 'MED']
# ['MD']
# ['MD']
# ['MD']
# 7
# 10
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['BS', 'DDS', 'FAGD']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# 9
# 10
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['BS', 'DDS', 'FAGD']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# 9
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 4
# ['MD']
# ['MD']
# ['EDSLPC']
# ['DC']
# 2
# 1
# ['MD']
# 1
# 2
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 4
# ['MD']
# ['DDS']
# ['DO']
# ['MD']
# 3
# 1
# ['MD']
# 1
# 3
# ['EDD']
# ['MD']
# 2
# 2
# ['MD']
# ['DDS']
# 2
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['MD']
# ['MD']
# 3
# 1
# ['MD', 'PHD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 4
# ['MD']
# ['MD', 'PHD']
# ['MD']
# ['MD']
# 4
# 1
# ['MD']
# 1
# 1
# ['DDS']
# 1
# 2
# ['MD', 'FACEP']
# ['MD']
# 2
# 2
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MDD']
# 0
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 2
# ['MD']
# 2
# 10
# ['MD']
# ['DC']
# ['DMD']
# ['DDS']
# ['DO']
# ['MD']
# ['DIVE', 'IDC']
# ['ATC']
# ['MA', 'LPC']
# 4
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['PT']
# ['MD']
# 2
# 10
# ['MD']
# ['DC']
# ['MD']
# ['MD']
# ['MA', 'LCPC']
# ['MD']
# ['DDS']
# ['MSW']
# ['MD']
# ['MD']
# 7
# 8
# ['MD']
# ['MD', 'PC']
# ['RPH']
# ['DDS']
# ['MD']
# ['DMD']
# ['RPH']
# 5
# 1
# ['LCSW']
# 0
# 1
# ['OTRL']
# 0
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 4
# ['MD']
# ['MD']
# ['MD']
# ['OD']
# 3
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['PHD']
# ['MS', 'CCCSLP']
# 2
# 1
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 5
# ['DO']
# ['DPM']
# ['MD']
# ['PAC']
# ['MD']
# 2
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['LIC', 'AC']
# ['LPC', 'NCC', 'CAP']
# ['MD']
# ['PHD']
# 8
# 8
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['PHD']
# ['MD']
# ['OD']
# 7
# 2
# ['MD']
# ['OD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['LPCP']
# ['MD']
# ['MD']
# ['PAC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 8
# 10
# ['MD']
# ['LCSW']
# ['MD']
# ['DC']
# ['DO']
# ['DDS']
# ['MSW']
# ['PHARM', 'D']
# ['CCS']
# 4
# 2
# ['MD']
# ['MD']
# 2
# 2
# ['MD']
# ['DDS']
# 2
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['DO']
# 1
# 2
# ['MD']
# ['DC']
# 1
# 1
# ['MD']
# 1
# 5
# ['RPH']
# ['DPM']
# ['PH', 'D']
# ['PHD']
# ['MD']
# 2
# 4
# ['MD']
# ['MD']
# ['DMD']
# ['MD']
# 3
# 9
# ['MD']
# ['MD']
# ['MD']
# ['DC']
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# 7
# 1
# ['MD']
# 1
# 10
# ['DPM']
# ['MD']
# ['MD']
# ['MD']
# ['PHD']
# ['MBCHB']
# ['DDS']
# ['EDD']
# ['DDS']
# ['DDS']
# 7
# 4
# ['MD']
# ['DPM']
# ['DC']
# ['DC']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['DPM']
# ['DPM']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DMD']
# ['MD']
# ['DPM']
# ['MD']
# 6
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MPT']
# ['LCPC']
# ['MD']
# ['DMD']
# ['DMD']
# ['LCSW']
# ['MD']
# 5
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['MD']
# ['MD']
# 3
# 4
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# 3
# 5
# ['MD']
# ['DDS']
# ['DDS']
# ['DDS']
# ['MD']
# 5
# 3
# ['MD']
# ['MD']
# ['DC']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 4
# ['MD']
# ['MD']
# ['PSYD']
# ['LMSW']
# 2
# 3
# ['DC']
# ['MD']
# ['MD']
# 2
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['PH', 'D']
# ['DDS']
# ['MD']
# ['MD']
# 9
# 6
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# ['MD']
# 5
# 2
# ['MD']
# ['MD']
# 2
# 3
# ['DPM']
# ['MD']
# ['PHD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 7
# ['MD']
# ['MD']
# ['MA', 'MFT']
# ['MSW']
# ['MD']
# ['DPT', 'CSCS']
# ['LMSW']
# 3
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['RPH']
# ['MD']
# ['MS']
# ['OD']
# ['ARNP']
# ['MD']
# ['MD']
# 6
# 10
# ['MD']
# ['MD']
# ['MD']
# ['RPH']
# ['MD']
# ['MS']
# ['OD']
# ['ARNP']
# ['MD']
# ['MD']
# 6
# 6
# ['MD']
# ['PHD']
# ['RAC']
# ['MD']
# ['DDS']
# ['DMD']
# 4
# 2
# ['MD']
# ['MD']
# 2
# 4
# ['MD']
# ['DDS']
# ['OD']
# ['MA']
# 2
# 3
# ['MD']
# ['RPH']
# ['ATC']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['DC']
# ['MD']
# ['MD']
# ['MD']
# 9
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 10
# 10
# ['MD']
# ['PHD']
# ['MD']
# ['MD']
# ['MD']
# ['OD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 9
# 10
# ['MD']
# ['PHD']
# ['MD']
# ['MD']
# ['MD']
# ['OD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 9
# 8
# ['MD']
# ['OD']
# ['DMD']
# ['OD']
# ['BS', 'PHARM']
# ['DDS']
# ['MD']
# ['DPM']
# 3
# 10
# ['PHARMACIST']
# ['MD']
# ['MD']
# ['OD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 8
# 1
# ['MD']
# 1
# 1
# ['MD', 'PHD']
# 1
# 1
# ['MD']
# 1
# 9
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PT', 'ATC']
# ['OD']
# ['MD']
# ['PAC']
# 6
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MPT']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# ['D', 'D', 'S']
# ['MD']
# ['DO']
# ['DC']
# ['MD', 'PA']
# 6
# 4
# ['MD']
# ['MD']
# ['DO']
# ['MD']
# 3
# 4
# ['OD']
# ['MD']
# ['MD']
# ['DC']
# 2
# 2
# ['NP']
# 1
# 2
# ['MD', 'PHD']
# ['DDS']
# 2
# 4
# ['MD']
# ['LCSW']
# ['JONATHAN', 'GOODSON']
# ['DC']
# 1
# 4
# ['MD']
# ['MD']
# ['MD']
# ['MSSW']
# 3
# 10
# ['PSYD']
# ['MD']
# ['MD']
# ['DMD']
# ['MD']
# ['MD']
# ['MD']
# ['NP']
# ['OT']
# ['MD']
# 6
# 10
# ['MD']
# ['MD']
# ['MD']
# ['AT']
# ['DPM']
# ['MD']
# ['MD']
# ['MD']
# ['DMD']
# ['MD']
# 7
# 10
# ['MD']
# ['MD']
# ['MD']
# ['AT']
# ['DPM']
# ['MD']
# ['MD']
# ['MD']
# ['DMD']
# ['MD']
# 7
# 2
# ['MD']
# ['DPT']
# 1
# 10
# ['FNPC']
# ['MD']
# ['MD']
# ['MD']
# ['MRC']
# ['MD']
# ['MD']
# ['MD', 'FRCPC', 'PLLC']
# ['DDS']
# ['PT']
# 7
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 10
# 8
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['IDCSMDR']
# ['PT', 'DPT']
# 6
# 10
# ['DMD']
# ['OD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PHD']
# ['MD']
# ['MD']
# 8
# 10
# ['DMD']
# ['OD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PHD']
# ['MD']
# ['MD']
# 8
# 3
# ['MD']
# ['PH', 'D']
# ['OD']
# 1
# 10
# ['PHD']
# ['DO']
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PT', '', 'CPT']
# ['MD']
# 7
# 10
# ['PHD']
# ['DO']
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PT', '', 'CPT']
# ['MD']
# 7
# 1
# ['MD', 'PHD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['LCSW']
# 0
# 2
# ['MD']
# ['MD']
# 2
# 4
# ['PHD']
# ['MD']
# ['MD']
# 4
# 5
# ['MD']
# ['DMD']
# ['MSW']
# ['MD']
# ['OTRL']
# 2
# 3
# ['MD', 'PHD']
# ['MD']
# ['DO']
# 2
# 3
# ['MD', 'PHD']
# ['MD']
# ['DO']
# 2
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['NP']
# 1
# 2
# ['LCSW']
# ['MD', 'PHD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 7
# ['MD']
# ['MD']
# ['PHD']
# ['MD']
# ['MD']
# ['DC']
# ['LPTA']
# 5
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MA', 'LLP']
# ['MD']
# ['MD']
# ['MD']
# ['PAC']
# ['MD']
# 8
# 1
# ['DDS']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 10
# ['LCSWR']
# ['DO']
# ['MD']
# ['DC']
# ['DDS']
# ['ATC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 6
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['OD', 'PLC']
# ['DDS']
# ['MD']
# ['DDS']
# ['DO']
# ['DMD']
# ['LPN']
# ['MD']
# 6
# 10
# ['MD']
# ['MD']
# ['PHD']
# ['MSPT']
# ['DPM']
# ['RNBSN', 'MTNMP']
# ['MS', 'AUDIOLOGY']
# ['PHD', 'PSYCHOLOGIST']
# ['DC']
# 5
# 1
# ['MD']
# 1
# 0
# 0
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['DMD']
# ['MD']
# 2
# 10
# ['DPM']
# ['MD']
# ['MD']
# ['DC']
# ['DPM']
# ['PHD']
# ['MD']
# ['MD', 'PHD']
# ['CADCIII']
# ['MD']
# 6
# 10
# ['DPM']
# ['MD']
# ['MD']
# ['DC']
# ['DPM']
# ['PHD']
# ['MD']
# ['MD', 'PHD']
# ['CADCIII']
# ['MD']
# 6
# 10
# ['MD']
# ['PA']
# ['MD']
# ['DPM']
# ['MD']
# ['DDS']
# ['DC']
# ['MD']
# ['NMD']
# ['DDS']
# 6
# 10
# ['MD']
# ['MD']
# ['OD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PHD']
# ['MD']
# ['MD']
# 9
# 9
# ['CRNA']
# ['MD']
# ['MS', 'DC']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# ['DC']
# 6
# 9
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DPM']
# ['DDS']
# ['DMD']
# ['MD']
# ['CRNA']
# 6
# 9
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DPM']
# ['DDS']
# ['DMD']
# ['MD']
# ['CRNA']
# 6
# 6
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DMD']
# ['MD']
# 5
# 9
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['DMD']
# 8
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 10
# 1
# ['MD']
# 1
# 8
# ['MD']
# ['MD']
# ['MD']
# ['PAC']
# ['QMHA']
# ['MD']
# ['CDPT']
# 5
# 9
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# 7
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DMD']
# ['LMT']
# ['MD']
# ['RPH']
# ['MA']
# ['DDS']
# 6
# 1
# ['MD']
# 1
# 9
# ['MD']
# ['MD']
# ['MD']
# ['MA', 'MCJ']
# ['MD']
# ['LPC']
# ['MD']
# ['DCQME']
# ['MD']
# 6
# 9
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PT']
# ['PHD']
# ['DMD']
# ['PHD']
# ['DDS']
# 7
# 9
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PT']
# ['PHD']
# ['DMD']
# ['PHD']
# ['DDS']
# 7
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 3
# ['MA', 'DPM', 'MD']
# ['MD']
# ['PSYD']
# 2
# 1
# ['MD']
# 1
# 7
# ['PA', 'C']
# ['MD']
# ['MD']
# ['MD']
# ['DCFICC']
# ['MA']
# 4
# 10
# ['MD', 'FACC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DPM']
# ['MD']
# ['MD']
# ['OD']
# 8
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['PT']
# ['MD']
# ['RPH']
# ['DPM']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# 7
# 10
# ['MD']
# ['MD', 'PHD']
# ['MD']
# ['LCSW']
# ['MD']
# ['DDS', 'MS']
# ['MD']
# ['DDS']
# ['CAP']
# 8
# 5
# ['MD']
# ['MD']
# ['MD']
# ['DC']
# ['MD']
# 4
# 4
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 4
# 4
# ['MD']
# ['CRNA']
# ['MD']
# ['DMD']
# 2
# 3
# ['MD']
# ['MD']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 8
# ['DPM']
# ['MD']
# ['DC']
# ['RPH']
# ['PHD']
# ['RPH']
# ['MA', 'LMHC']
# 3
# 5
# ['MD']
# ['MD']
# ['MD']
# ['DDS', 'MSD']
# 5
# 4
# ['MD']
# ['MD', 'PHD']
# ['MD']
# 4
# 7
# ['MD']
# ['MD']
# ['DMD']
# ['LCSW']
# ['MD']
# ['MD']
# ['MD']
# 5
# 1
# ['MD']
# 1
# 3
# ['DDS']
# ['MD']
# ['MD']
# 3
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['DDS']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD', 'FAPA', 'PC']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['OD']
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 2
# ['PHD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# 2
# 1
# 1
# 3
# ['MD']
# ['MD']
# ['DDS']
# 3
# 1
# ['MD']
# 1
# 7
# ['MD']
# ['DO']
# ['DDS']
# ['DC']
# ['MD']
# ['PHD']
# ['DDS']
# 5
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MS']
# 1
# 2
# ['MD']
# 2
# 1
# ['DDS']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 6
# ['DC']
# ['MD']
# ['DO']
# ['LICDCCSLSW']
# ['CSA']
# 2
# 5
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 5
# 3
# ['MD']
# ['MD']
# ['MD']
# 3
# 3
# ['MD']
# ['MD']
# ['COTAL']
# 2
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 4
# ['NP']
# ['MD']
# ['MD']
# ['NP']
# 2
# 2
# ['MD']
# ['MD']
# 2
# 4
# ['PA']
# ['MD']
# ['DDSMAGD']
# ['DDS']
# 2
# 9
# ['MD']
# ['OD']
# ['DC']
# ['MD']
# ['MD']
# ['DC']
# ['CRNA']
# ['PTA']
# 4
# 9
# ['MD']
# ['PHARMD']
# ['DMD']
# ['OD']
# ['MD']
# ['MD']
# ['DO', 'ATC']
# ['RPH']
# ['MASTER', 'OF', 'SCIENCE']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['DO']
# 0
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 7
# ['CHIROPRACTOR']
# ['DO']
# ['MD']
# ['DDS']
# ['DDS']
# ['MD']
# 5
# 1
# ['MD']
# 1
# 4
# ['MD']
# ['MD']
# ['MD']
# ['PA']
# 3
# 10
# ['PHD']
# ['MD']
# ['PAC']
# ['DC']
# ['MD']
# ['MD']
# ['DDS', 'FAGD']
# ['OD']
# ['MD']
# ['DC']
# 6
# 10
# ['MD']
# ['MD']
# ['MD']
# ['PHD']
# ['MD']
# ['MD']
# ['OD']
# ['MD']
# ['MD']
# ['PA', 'C']
# 8
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['LP']
# ['DDS']
# ['MD']
# ['MD']
# 9
# 4
# ['MD']
# ['DO']
# ['DC']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['PHD']
# ['MD']
# 2
# 9
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PAC']
# ['MD']
# ['DO']
# ['MD']
# ['DO']
# 6
# 2
# ['MD']
# ['DO']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['DC']
# ['MD']
# ['MD']
# ['DDS', 'MS']
# ['MD']
# ['BS', 'RSW']
# ['DDS']
# ['CRNA']
# ['DDS']
# ['DDS']
# 7
# 10
# ['MD']
# ['DC']
# ['DDS']
# ['MD']
# ['DDS']
# ['MA', 'LPA']
# ['RPH']
# ['CRNA']
# ['OD']
# ['MDPHD']
# 4
# 2
# ['MD']
# ['MD']
# 2
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MPT']
# ['MD']
# ['DDS']
# ['MD']
# ['PHD']
# ['DO']
# 8
# 8
# ['MD']
# ['MD']
# ['MD']
# ['DC']
# ['MS', 'BCBA']
# ['MD']
# 6
# 10
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['LMP']
# 9
# 10
# ['MD']
# ['DPM']
# ['MD']
# ['MD']
# ['LCSW']
# ['DMD']
# ['DDS']
# ['REGISTERED', 'NURSE']
# ['DDS']
# 6
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['FNP']
# ['PT']
# ['PT', 'DPT']
# ['DC']
# ['DMD']
# 5
# 6
# ['MD']
# ['MD']
# ['MSN', 'FNPC']
# ['ATC']
# ['DPM']
# ['LMHC']
# 2
# 1
# ['MD']
# 1
# 10
# ['PHD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['DC']
# ['DDS']
# ['DDS']
# 9
# 10
# ['MD']
# ['MD']
# ['DPM']
# ['MD']
# ['MED', 'LPC']
# ['PHD']
# ['MD']
# ['DDS']
# ['DO']
# ['MD']
# 7
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MSW']
# ['MD']
# ['PHD']
# ['MD']
# ['OD']
# ['MD']
# 8
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['DMD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 3
# ['CPED']
# ['MD']
# 2
# 1
# ['NP']
# 0
# 1
# ['MD']
# 1
# 1
# ['DC']
# 0
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 8
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['RPH']
# ['DC']
# 6
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 4
# ['MD']
# ['OTRL', 'CHT']
# ['MD']
# 3
# 10
# ['MD']
# ['MD']
# ['MD']
# ['AUD']
# ['MD']
# ['MFT']
# ['PHD']
# ['PSYD']
# ['RPH']
# ['MD']
# 6
# 2
# ['MD']
# ['MD']
# 2
# 4
# ['MD']
# ['MD']
# ['MD']
# ['RDS']
# 3
# 2
# ['MD']
# ['MD']
# 2
# 1
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['PA']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['DMD']
# 1
# 2
# ['PHD']
# ['DO']
# 1
# 2
# ['MD']
# ['DDS']
# 2
# 6
# ['MD']
# ['DMD']
# ['OD']
# ['CRNA']
# ['THD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 5
# ['MD']
# ['PAC']
# ['PHD', 'LCSW']
# ['LMP']
# ['DO']
# 2
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 9
# ['MD']
# ['OD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['DC']
# ['ANP']
# 6
# 2
# ['MD']
# ['MD', 'PHD']
# 2
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['PHYSICIANS', 'ASSISTAN']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PHD']
# ['MD']
# ['PHD']
# 9
# 8
# ['MD']
# ['MD']
# ['MD']
# ['LCSW']
# ['DDS']
# ['MD']
# ['PHD']
# ['MD']
# 7
# 2
# ['OD']
# ['LPC']
# 0
# 2
# ['DDS']
# ['DMD']
# 1
# 5
# ['PT']
# ['DDS']
# ['DDS']
# ['MD']
# ['LCSW']
# 3
# 2
# ['DDS']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['NP']
# 1
# 0
# 0
# 1
# ['MD']
# 1
# 9
# ['OD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 8
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 3
# ['MD']
# ['DO']
# 2
# 9
# ['MD', 'MBA']
# ['DDS']
# ['OD']
# ['DO']
# ['DDS']
# ['DC']
# ['MD']
# ['PAC']
# ['RPH']
# 4
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MFT']
# ['MD']
# 1
# 3
# ['MD']
# ['DDS']
# ['LCSWQMHPMSW']
# 2
# 1
# ['MD']
# 1
# 7
# ['CSA']
# ['PHD']
# ['DDS']
# ['DC']
# ['OT']
# ['MD']
# 4
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# 2
# 3
# ['MD']
# ['ATC', 'CSCS', 'USAW']
# ['PSYD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['MS', 'ATC', 'CSCS']
# ['MSW']
# ['MD']
# ['PHARMACY', 'TECHNICIAN']
# ['MD']
# 7
# 10
# ['MD']
# ['DC']
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['PAC']
# ['MD']
# ['DO']
# ['DDS', 'MSD']
# 6
# 10
# ['MD']
# ['MD']
# ['DDS']
# ['PA']
# ['MD']
# ['DC']
# ['PT']
# ['PA']
# ['DO']
# ['MD']
# 5
# 5
# ['MD']
# ['MD']
# ['BA']
# ['PHD']
# 4
# 10
# ['MD']
# ['ATCL']
# ['MD']
# ['MD']
# ['MSW']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 8
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['DPM']
# 0
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['M', 'D']
# 0
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 4
# ['DMD']
# ['MD']
# ['MD']
# ['DMD']
# 2
# 4
# ['DMD']
# ['MD']
# ['MD']
# ['DMD']
# 2
# 2
# ['MD']
# ['MD']
# 2
# 3
# ['DPM']
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['RPH']
# 0
# 7
# ['DMD']
# ['DDS']
# ['MD']
# ['DDS']
# ['DDS']
# ['MD']
# ['MD']
# 6
# 6
# ['MD']
# ['CRNA']
# ['MD']
# ['LCSW']
# ['MD']
# ['DO']
# 3
# 10
# ['MD']
# ['DO']
# ['DPM']
# ['CRNA']
# ['MD']
# ['CRNA']
# ['MD']
# ['MD']
# ['DDS']
# ['DDS']
# 6
# 10
# ['MD']
# ['DO']
# ['DPM']
# ['CRNA']
# ['MD']
# ['CRNA']
# ['MD']
# ['MD']
# ['DDS']
# ['DDS']
# 6
# 1
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# 1
# 3
# ['MD']
# ['PAC']
# ['MD']
# 2
# 2
# ['MD']
# ['PTMHSCSCS']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['DMD']
# 1
# 3
# ['OD']
# ['MD']
# ['DPT']
# 1
# 3
# ['OD']
# ['MD']
# ['DPT']
# 1
# 1
# ['DC']
# 0
# 2
# ['MD']
# 2
# 1
# ['MD']
# 1
# 4
# ['DC']
# ['MD']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# 1
# 1
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 5
# ['MD']
# ['MD', 'MS']
# ['AA']
# ['PAC']
# ['PHD']
# 3
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['DDS']
# 2
# 5
# ['MD']
# ['MD']
# ['MD']
# ['DDS', 'MS']
# ['MA']
# 4
# 1
# 1
# 10
# ['MD', 'PHD']
# ['ATC']
# ['DDS']
# ['LICENSED', 'OPTICIAN']
# ['MD']
# ['MD']
# ['MPT']
# ['MD', 'DDS', 'PHD']
# ['D', 'D', 'S']
# ['MS', 'MD']
# 6
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['DO']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['RPH']
# ['PHARMACIST']
# ['PSYD']
# 6
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['PT']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 4
# ['DO']
# ['MD']
# ['LCSW']
# 2
# 7
# ['DDS']
# ['DMD']
# ['DDS']
# ['RPT']
# ['PHD']
# ['MA']
# ['MD']
# 4
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# ['MD']
# ['PT']
# ['DC']
# ['DDS']
# ['DDS']
# ['MD']
# 7
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# ['PAC']
# ['OTRL', 'CHT']
# 8
# 1
# ['MD']
# 1
# 3
# ['DDS']
# ['DDS']
# ['DC']
# 2
# 10
# ['OD']
# ['MD']
# ['MED', 'PT', 'ATC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['NBCHIS']
# ['RPH']
# 6
# 1
# ['MD', 'PHD']
# 1
# 1
# ['MD']
# 1
# 1
# ['CRPH']
# 0
# 2
# ['MD']
# ['DO']
# 1
# 5
# ['MD']
# ['MD']
# ['DDS']
# ['RPT']
# ['LMP']
# 3
# 1
# ['MD']
# 1
# 7
# ['DMD']
# ['OD']
# ['PHD', 'LMFT']
# ['DO']
# 4
# 1
# ['MD']
# 1
# 3
# ['DDSPSMAGD']
# ['MD']
# 2
# 8
# ['DC']
# ['DDS']
# ['MD']
# ['MD']
# ['OTRL']
# ['PHD', 'LPC', 'RPT']
# ['RN']
# 5
# 2
# ['DDS']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 6
# ['DC', 'MD']
# ['MD']
# ['PHARMD']
# ['PHARMD']
# ['AA']
# 3
# 10
# ['DO']
# ['MD']
# ['MD']
# ['DO']
# ['PSYD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 7
# 10
# ['DO']
# ['MD']
# ['MD']
# ['DO']
# ['PSYD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 7
# 8
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['LPC']
# ['MD']
# 7
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 6
# ['MD']
# ['BS']
# ['DDS']
# ['MD']
# ['MD', 'PHD']
# ['PT']
# 4
# 7
# ['MD']
# ['MD', 'PHD']
# ['DMD']
# ['MD']
# ['DC']
# ['RPH']
# 4
# 2
# ['MD']
# ['MD']
# 2
# 3
# ['DDS']
# ['MD']
# 3
# 6
# ['MD']
# ['MD']
# ['OD']
# ['LCSW']
# ['MD']
# ['MD']
# 4
# 3
# ['MD']
# ['MD']
# ['MD']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['MD']
# ['MD']
# 3
# 3
# ['MD']
# ['MD']
# ['MD']
# 3
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# ['PLMHP']
# ['MD']
# 9
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# ['PLMHP']
# ['MD']
# 9
# 8
# ['DDS']
# ['PA']
# ['MD']
# ['DDS']
# ['DC']
# ['RN', 'FA']
# ['MA']
# 4
# 10
# ['RPH']
# ['MD']
# ['PT']
# ['DDS']
# ['MD']
# ['MD']
# ['DC']
# ['MD']
# ['PHD']
# ['MD']
# 7
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DMD']
# ['MD']
# ['DPM']
# ['PT']
# ['MD']
# 7
# 4
# ['MD']
# ['PA']
# ['MD', 'MPH']
# 3
# 10
# ['MD']
# ['MD']
# ['MD']
# ['OD']
# ['PHD']
# ['MD']
# ['OPTOMETRIST']
# ['PHD']
# ['LMP']
# ['MD']
# 7
# 2
# ['DO']
# ['MD']
# 1
# 2
# ['DMD']
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MFT']
# ['MD']
# ['MD']
# ['MD']
# ['OD']
# ['SFIDC']
# ['DDS']
# 7
# 4
# ['DDS']
# ['MD']
# ['MD']
# ['MED']
# 3
# 10
# ['MD', 'MPH']
# ['MD', 'PHD']
# ['MD']
# ['MD', 'PA']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['RPH']
# 9
# 3
# ['MD']
# ['MD']
# ['LPN']
# 2
# 3
# ['DMD']
# ['MD']
# ['MD']
# 2
# 3
# ['DDS']
# ['MD']
# 3
# 1
# ['MA', 'SLPE']
# 0
# 4
# ['DO']
# ['MD']
# ['DDS']
# ['MD', 'PHD']
# 3
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['MD']
# ['DDS']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['ATC']
# ['OD']
# 1
# 1
# 1
# 10
# ['DMD']
# ['MD']
# ['PA']
# ['MPT', 'OCS']
# ['DO']
# ['OT']
# ['MD']
# ['RPH', 'MS']
# ['OPTICIAN']
# ['LCSW', 'BCD']
# 2
# 10
# ['MD']
# ['MD']
# ['DC']
# ['MD']
# ['DDS', 'MSD']
# ['DDS']
# ['MD']
# ['MS']
# ['MD', 'JD']
# ['CPO']
# 7
# 4
# ['NP']
# ['MD']
# ['MD']
# ['MA', 'LPC']
# 2
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['DDS']
# 2
# 6
# ['MD']
# ['PAC']
# ['MD']
# ['PHARMD']
# ['DO']
# ['MD']
# 3
# 10
# ['MD']
# ['MD']
# ['DDS']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# ['PAC']
# ['PA']
# ['MD']
# 8
# 10
# ['DDS']
# ['MD']
# ['RPH']
# ['CRNP']
# ['MD']
# ['RPH']
# ['MD']
# ['DDS']
# ['DDS']
# ['MD']
# 7
# 9
# ['MS']
# ['MD']
# ['PAC']
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# ['MD']
# ['MD']
# 6
# 10
# ['PHARM', 'D']
# ['MD']
# ['MD']
# ['MD']
# ['DMD', 'MD']
# ['BS', 'MLS', 'MBA', 'PD']
# ['DC']
# ['MD']
# ['MD']
# ['RPH']
# 6
# 10
# ['PHARM', 'D']
# ['MD']
# ['MD']
# ['MD']
# ['DMD', 'MD']
# ['BS', 'MLS', 'MBA', 'PD']
# ['DC']
# ['MD']
# ['MD']
# ['RPH']
# 6
# 10
# ['PHARM', 'D']
# ['MD']
# ['MD']
# ['MD']
# ['DMD', 'MD']
# ['BS', 'MLS', 'MBA', 'PD']
# ['DC']
# ['MD']
# ['MD']
# ['RPH']
# 6
# 10
# ['MD', 'PA']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PAC']
# ['MD']
# ['MD']
# ['DDS']
# 9
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DC']
# ['MD']
# ['CPO']
# ['DMD']
# ['DC']
# ['PAC']
# ['DO']
# 4
# 10
# ['MD']
# ['PA']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DMD', 'PC']
# ['DDS']
# ['DDS']
# ['OD']
# 7
# 10
# ['MD']
# ['LCSW']
# ['MA']
# ['MD']
# ['MD']
# ['MD']
# ['MD', 'PHD']
# ['DMD']
# ['DDS']
# ['OD']
# 6
# 10
# ['MD']
# ['MD']
# ['MD']
# ['PTDPT', 'OCS']
# ['DC']
# ['MD']
# ['MD', '', 'FACS']
# ['MD']
# ['MD']
# 8
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['DO']
# ['MD']
# ['PHD']
# ['RPH']
# ['MD']
# ['MD']
# ['DO']
# ['MD']
# 7
# 4
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 4
# 10
# ['MD']
# ['CRNA']
# ['MD']
# ['MD']
# ['PHARMD']
# ['MD']
# ['DPM']
# ['OD']
# ['MD']
# ['MD']
# 6
# 2
# ['MD']
# ['MD']
# 2
# 10
# ['MD']
# ['MD']
# ['MD', 'PHD']
# ['RPH']
# ['LPT']
# ['LMHC']
# ['MD']
# ['MD']
# ['RPH']
# 6
# 10
# ['DDS']
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['CRNA']
# ['MD']
# ['MD']
# 8
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 7
# ['MD']
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PSYD']
# 5
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['OD']
# 0
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['PHARMD']
# ['ND']
# ['MD']
# ['MD']
# ['MD']
# ['OD']
# ['MPT', 'MOMT']
# ['MD']
# 6
# 7
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['RC']
# ['MSW']
# ['PHD']
# 5
# 10
# ['DC']
# ['MD']
# ['OPTDISP']
# ['MD']
# ['OD']
# ['DC']
# ['MD']
# ['MD']
# ['PT']
# ['PHD']
# 5
# 4
# ['MD']
# ['DMD']
# ['JD', 'MSW']
# 2
# 4
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# 3
# 4
# ['MD']
# ['MD']
# ['MD', 'RVT', 'FACPH']
# ['MD']
# 4
# 3
# ['MD']
# ['MD']
# ['MD']
# 3
# 1
# ['MD']
# 1
# 10
# ['PSYD']
# ['MD']
# ['OD']
# ['MDMD']
# ['DDS']
# ['MD']
# ['MD']
# ['DDS']
# ['MFT']
# ['MD']
# 6
# 7
# ['DPM']
# ['DMD']
# ['DO']
# ['MD']
# ['MD', 'PHD']
# ['MD']
# ['MD']
# 4
# ...
# ['MD']
# ['MD']
# ['CRNA']
# 2
# 1
# ['DDS']
# 1
# 10
# ['AUD']
# ['DO']
# ['DDS']
# ['MD']
# ['PHD']
# ['MD']
# ['PHD']
# ['PT']
# ['MD']
# ['MD']
# 7
# 10
# ['DPM']
# ['MD']
# ['DC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 8
# 6
# ['MD']
# ['MD']
# ['RNFA']
# ['MHR', 'LADC']
# ['RN']
# 3
# 10
# ['OD']
# ['PHYSICAL', 'THERAPIST']
# ['MD']
# ['MD']
# ['DO']
# ['MD', 'PHD']
# ['CRNA']
# ['MD']
# 6
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# ['MD']
# ['MD']
# ['DDS']
# ['LMFT']
# ['DDS']
# ['MD']
# 8
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['NP']
# ['MD']
# ['MD']
# ['PAAA']
# ['MD']
# 8
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['NP']
# ['MD']
# ['MD']
# ['PAAA']
# ['MD']
# 8
# 10
# ['MD']
# ['PAC']
# ['MD']
# ['OD']
# ['MD']
# ['OD']
# ['MD']
# ['CRNA']
# ['MD']
# ['MD']
# 6
# 10
# ['MD']
# ['MD']
# ['PAC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DMD']
# ['MD']
# ['MD']
# 8
# 10
# ['MD']
# ['MD']
# ['PAC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DMD']
# ['MD']
# ['MD']
# 8
# 10
# ['MD']
# ['MD']
# ['DDS']
# ['DO']
# ['DO']
# ['RPH']
# ['LICENSEDPSYCHOLOGIST']
# ['MD']
# ['DC']
# ['MD']
# 5
# 10
# ['MD']
# ['MD']
# ['DDS']
# ['DO']
# ['DO']
# ['RPH']
# ['LICENSEDPSYCHOLOGIST']
# ['MD']
# ['DC']
# ['MD']
# 5
# 10
# ['DC']
# ['MD']
# ['MD']
# ['PHARMD']
# ['MD']
# ['DC']
# ['DPM']
# ['MD']
# ['PA', 'C']
# ['DPT']
# 4
# 10
# ['CNP']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PHD']
# ['MD']
# 9
# 10
# ['MD']
# ['MS', 'FNP']
# ['MD']
# ['DO']
# ['MD']
# ['DO']
# ['MD']
# ['DHSC', 'ARNP']
# ['DO']
# ['MD']
# 5
# 10
# ['MD']
# ['MD']
# ['DO']
# ['R', 'PH']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['DC']
# 7
# 10
# ['MD']
# ['MD']
# ['DO']
# ['R', 'PH']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['DC']
# 7
# 10
# ['MD']
# ['MD']
# ['DO']
# ['R', 'PH']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['DC']
# 7
# 10
# ['MD']
# ['MD']
# ['DO']
# ['R', 'PH']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['DC']
# 7
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['LCSW']
# 9
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['LCSW']
# 9
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['OD']
# ['MD']
# ['MD']
# ['RPH']
# ['MD']
# 8
# 10
# ['MD']
# ['CRNA']
# ['DO']
# ['RPT']
# ['MD']
# ['MD']
# ['MD']
# ['DMD']
# ['MD']
# ['DC']
# 5
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD', 'PHD']
# 1
# 9
# ['MD']
# ['DO']
# ['PAC']
# ['DPM']
# ['MD']
# ['DDS']
# ['DDS']
# ['MD']
# 6
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['CRNA']
# ['PT']
# ['MD']
# ['OD']
# ['MD']
# ['MD']
# 7
# 7
# ['MD']
# ['DO']
# ['PAC']
# ['DPH']
# ['DDS']
# ['DC']
# 3
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['DC']
# 1
# 2
# ['DPM']
# ['PHARMD']
# 0
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD', 'PHD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 7
# ['PHD']
# ['PHD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 7
# 5
# ['MD']
# ['MD', 'FACC']
# ['MD']
# ['MD']
# 5
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 0
# 0
# 5
# ['MD']
# ['MD']
# ['MD']
# ['OD', 'PHD']
# ['MD']
# 5
# 1
# ['MD']
# 1
# 7
# ['DPM']
# ['MD']
# ['MD']
# ['RPT']
# ['LCSW']
# 4
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['DC']
# ['MD']
# ['DO']
# ['MD']
# ['DO']
# ['DMD']
# ['DC']
# ['MD']
# 5
# 1
# ['STATE', 'LICENSED', 'HEARI']
# 0
# 2
# ['MD', 'CM']
# ['MD']
# 2
# 1
# ['MD', 'PH', 'D']
# 1
# 1
# ['MD']
# 1
# 6
# ['MD']
# ['MD']
# ['DDS', 'PC']
# ['MD']
# ['DDS']
# 6
# 1
# ['MD']
# 1
# 4
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 4
# 1
# ['MD', 'PHD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['PT']
# ['DDS']
# 2
# 2
# ['MD']
# ['PHD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['OD']
# ['ATC']
# ['PT']
# ['MD']
# ['MD']
# ['PA']
# ['PHD']
# ['MD']
# 6
# 10
# ['MD']
# ['NP']
# ['MD']
# ['DDS']
# ['MD']
# ['DDS']
# ['DO']
# ['DDS']
# ['', 'MA', 'PCI', 'MRAS']
# 7
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['M', 'D']
# ['DMD']
# ['MD']
# ['FRA']
# 7
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['DO']
# 0
# 1
# 1
# 1
# ['MD']
# 1
# 10
# ['ACNP']
# ['MD']
# ['MD']
# ['MD']
# ['ATC', 'DPT']
# ['DDS', 'MSD']
# ['DDS']
# ['DDS']
# ['DDS']
# ['MD']
# 8
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['OD']
# ['MD']
# 9
# 3
# ['DC']
# ['MD']
# ['MD']
# 2
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PAC']
# ['MD', 'MPH']
# ['DDS']
# ['MD']
# ['PHD']
# 9
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 10
# 2
# ['MD']
# ['MD']
# 2
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DDS', 'PC']
# 10
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PHD']
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# 9
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DPM']
# ['DPM']
# ['MD']
# ['MD']
# ['MD']
# ['PHD']
# ['DC']
# 7
# 10
# ['MD']
# ['PAC']
# ['MD']
# ['PHD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DMD']
# 8
# 7
# ['PT']
# ['MD']
# ['DDS']
# ['APRN']
# ['CRNA']
# ['MD']
# ['MD']
# 4
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DMD']
# ['MD']
# ['MD']
# ['MD']
# 9
# 10
# ['MD']
# ['MD']
# ['CRNA']
# ['PHD']
# ['MD']
# ['MD']
# ['DMD']
# ['PA']
# ['RPH']
# 6
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 9
# ['LCSW']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['RSS']
# ['PHD']
# ['MSEDBCBA']
# ['MD']
# 6
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 4
# ['LCSW']
# ['MD']
# ['CNP']
# ['DMD']
# 1
# 9
# ['MD']
# ['MD']
# ['PT']
# ['MD']
# ['MFT']
# ['DDS']
# ['DDS']
# ['DDS']
# ['MD']
# 7
# 2
# ['MD']
# ['LMHC']
# 1
# 10
# ['MD']
# ['MD']
# ['CRNA']
# ['DPM']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DC']
# 7
# 8
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# ['MD']
# ['PAC']
# ['PHD']
# 6
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['DMD']
# 0
# 1
# ['MD']
# 1
# 5
# ['MD']
# ['MD']
# ['DC']
# ['MD']
# ['MD']
# 4
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 6
# ['MD']
# ['MD']
# ['MD']
# ['COTA', 'L']
# ['MSW', 'LGSW']
# 4
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DMD']
# ['PT']
# ['MD']
# ['DO']
# ['PAC']
# ['DO']
# ['LAC']
# 4
# 8
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 8
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MS']
# 1
# 10
# ['DC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# ['MD']
# ['DPM']
# 7
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DMD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# 9
# 10
# ['MD']
# ['DMD']
# ['MD']
# ['MS', 'ATC']
# ['MD']
# ['MD']
# ['LICSW']
# ['DDS']
# ['MD']
# 7
# 10
# ['MD']
# ['DMD']
# ['MD']
# ['MS', 'ATC']
# ['MD']
# ['MD']
# ['LICSW']
# ['DDS']
# ['MD']
# 7
# 6
# ['MD']
# ['LMHC']
# ['PHD']
# ['MD']
# ['MD']
# 5
# 9
# ['DC']
# ['MD']
# ['MD']
# ['APN']
# ['RPH']
# ['MD']
# ['PHARMD']
# ['MA']
# 4
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 5
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PAC']
# 4
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 8
# ['DDS']
# ['CRNA']
# ['MD']
# ['DDS']
# ['DC']
# ['DDS']
# ['MD']
# ['MD']
# 6
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['OD']
# 0
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['MD']
# ['DDS']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 3
# ['NP']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['PHD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DPM']
# ['MD']
# ['MD']
# ['DC']
# ['MD']
# ['DO']
# ['MA', 'CCCA']
# 6
# 9
# ['OD']
# ['DC']
# ['MD']
# ['OD']
# ['PAC']
# ['MD']
# ['MD']
# ['PT']
# ['DO']
# 3
# 10
# ['MD']
# ['DPH']
# ['MD']
# ['RPH']
# ['MD']
# ['PHARMD']
# ['MD']
# ['PHARMD']
# ['DO']
# ['MD']
# 5
# 1
# 1
# 1
# ['MD']
# 1
# 3
# ['RPH']
# ['DDS']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 9
# ['MD']
# ['MD']
# ['PAC']
# ['MD']
# ['MD']
# ['MD']
# ['DMD']
# ['DC']
# ['PT']
# 5
# 3
# ['MD']
# ['MD']
# ['MD']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 10
# ['MD']
# ['MD']
# ['MD']
# ['PHD', 'MD']
# ['PHD']
# ['MD']
# ['MD']
# ['OD']
# ['MD']
# ['MD']
# 9
# 10
# ['MD']
# ['MD']
# ['MD']
# ['PHD', 'MD']
# ['PHD']
# ['MD']
# ['MD']
# ['OD']
# ['MD']
# ['MD']
# 9
# 4
# ['DMD']
# ['MD']
# ['DDS']
# ['LCSW']
# 2
# 10
# ['MD']
# ['MD']
# ['DO']
# ['MD']
# ['DMD']
# ['MD']
# ['DC']
# ['LAC']
# ['OD']
# 5
# 10
# ['MD']
# ['MD']
# ['MD']
# ['LPC', 'DMIN']
# ['MD']
# ['MD']
# ['NP']
# ['MD']
# ['MD']
# ['MD']
# 8
# 10
# ['MD']
# ['MD']
# ['MD']
# ['LCSW']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 9
# 1
# ['MD']
# 1
# 1
# ['MDPHD']
# 0
# 2
# ['MD']
# ['DDS']
# 2
# 4
# ['MD']
# ['DO']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 6
# ['MD']
# ['MD']
# ['MSN', 'FNPBC']
# ['DMD']
# ['MD']
# 4
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 10
# ['OD']
# ['MD']
# ['PHD']
# ['DDS']
# ['MD']
# ['DPT']
# ['NP']
# ['CNS', 'IN', 'ADULT', 'CARE']
# ['DO']
# 5
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 7
# ['PHARMD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DDS', 'MS']
# ['MD']
# 6
# 3
# ['MD']
# ['MD']
# ['MHPP']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['DPM']
# ['CRNA']
# ['DC']
# ['PA']
# ['OD']
# ['DDS']
# ['MD']
# ['DC']
# ['DO']
# ['DC']
# 2
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# ['PA']
# ['MD']
# ['MSPT']
# ['MD']
# ['LPC', 'LMFT']
# ['FNP']
# 5
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD', 'MACP']
# 1
# 2
# ['DC']
# ['MD']
# 1
# 10
# ['DMD']
# ['CRNA']
# ['OD']
# ['MD']
# ['MD']
# ['MLSW']
# ['OD']
# ['MD']
# ['MD']
# ['MD']
# 5
# 3
# ['MD']
# ['MD']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['LICPSY']
# ['DC']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MSW', 'LCSW']
# 1
# 1
# ['MD', 'MPH']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# 10
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['PHARM', 'D']
# ['CAC']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['DDS']
# 2
# 7
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['DDS']
# ['MA', 'LCSW']
# ['MD']
# 6
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['MD']
# ['MD']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PHD']
# ['MD']
# 10
# 7
# ['DC']
# ['MD', 'PHD']
# ['DDS']
# ['MD']
# ['MD']
# ['PHD']
# 6
# 4
# ['MD']
# ['DDS']
# ['OD']
# ['MD']
# 3
# 1
# ['MD']
# 1
# 9
# ['MD']
# ['DMD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PHARM', 'D']
# 7
# 10
# ['DC']
# ['MD']
# ['DDS', 'MD']
# ['PHD']
# ['MD']
# ['MD']
# ['CRNA']
# ['MD']
# ['MD']
# ['DPM']
# 7
# 7
# ['MD']
# ['DC']
# ['CRNA']
# ['LICSW']
# ['MD']
# ['DC']
# ['DMD']
# 2
# 10
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 9
# 1
# ['MD']
# 1
# 10
# ['CRNA']
# ['DDS']
# ['MD']
# ['DO']
# ['LCSW']
# ['DDS']
# ['MD']
# ['PHD']
# ['MD']
# ['MD']
# 7
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# ['DPM']
# ['MD']
# ['MD']
# ['OD']
# 7
# 2
# ['MD']
# ['DMD']
# 1
# 6
# ['MD']
# ['MD']
# ['ACMHC']
# ['MD']
# 5
# 3
# ['MD']
# ['MD']
# ['DDS']
# 3
# 1
# ['DDS']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['ATC']
# 1
# 4
# ['OD']
# ['MD']
# ['DO']
# ['PSYCHOLOGIST']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 8
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DMD']
# ['PHD']
# ['MD']
# ['MD']
# 7
# 1
# ['MD']
# 1
# 8
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PT']
# ['PHYSICIAN', 'ASSISTANT']
# ['MD']
# ['DDS']
# 6
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD', 'PHD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['DDS']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['DDS']
# 2
# 3
# ['CRNA']
# ['MD']
# ['MD']
# 2
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PTBSMA']
# ['RPH']
# ['DO']
# ['D', 'O']
# 6
# 1
# ['MD']
# 1
# 6
# ['MD']
# ['MD', 'CM']
# ['MD']
# ['MD']
# ['MD']
# ['LPC']
# 5
# 1
# ['MD']
# 1
# 3
# ['PT', 'OCS']
# ['MD']
# ['MD']
# 2
# 9
# ['DDS']
# ['MD', 'MPH']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PHD', 'APRN']
# ['PH', 'D']
# ['DMD']
# 7
# 10
# ['MD']
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['LPC', 'LMFT']
# ['MD']
# 8
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['PAC']
# ['DO']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['DDS']
# ['PHARMD']
# 7
# 10
# ['MD']
# ['MD']
# ['PAC']
# ['DO']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['DDS']
# ['PHARMD']
# 7
# 3
# ['MD']
# ['MD']
# 3
# 6
# ['DPM']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# 5
# 8
# ['MD']
# ['MD']
# ['MD']
# ['DO']
# ['PHD']
# 7
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['PHD']
# ['MD']
# ['MD']
# ['DDS']
# ['DO']
# ['PHD']
# ['MD']
# 9
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD', 'PHD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['OD']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['DDS']
# 9
# 8
# ['MD']
# ['MD']
# ['MD']
# ['PHD', 'MD']
# ['DDS']
# ['MD', 'PHD']
# ['MC']
# ['DDS']
# 7
# 10
# ['MD']
# ['MDMPH']
# ['MD']
# ['MD']
# ['DO']
# ['MD']
# ['MD']
# ['DO']
# ['OD']
# ['MD']
# 6
# 3
# ['MD']
# ['DDS', 'MSD']
# ['CASAC']
# 2
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 10
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['DPM']
# ['DO']
# ['MD']
# ['OPTICIANTECHNICIAN']
# ['MD']
# 7
# 10
# ['MD']
# ['EX']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 9
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 6
# ['MD']
# ['MD']
# ['PHD']
# ['DPM']
# ['MD']
# ['DMD']
# 4
# 2
# ['MD']
# ['MD']
# 2
# 3
# ['MD']
# ['MD']
# ['MD']
# 3
# 9
# ['CRNA']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DC']
# ['MD']
# ['EDSNCCLPCSCSAT']
# 6
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 10
# 1
# ['AAC']
# 0
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['DDS']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 4
# ['PAC']
# ['MD']
# ['MD']
# ['MD']
# 3
# 10
# ['DO']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['RPH']
# ['MD']
# ['DMD', 'MD']
# ['DC']
# 7
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['MD']
# ['MD']
# 3
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 4
# ['DDS']
# ['CPED']
# ['MD']
# 3
# 10
# ['MD']
# ['MD']
# ['DMD']
# ['MD']
# ['DDS']
# ['MD']
# ['DO']
# ['DCLAC']
# ['DO']
# ['DO']
# 5
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 10
# 10
# ['MD']
# ['MD']
# ['MD']
# ['OD']
# ['LPC']
# ['DC']
# ['MD']
# ['MD', 'PA']
# ['DDS']
# 7
# 1
# ['MD', 'MS']
# 1
# 10
# ['LCSW']
# ['MD']
# ['MD', 'FACOG']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['PA', '', 'C']
# ['PT']
# ['MD']
# 7
# 10
# ['PA']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['DO']
# ['LISW']
# ['MD']
# ['MD']
# 7
# 10
# ['PA']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['DO']
# ['LISW']
# ['MD']
# ['MD']
# 7
# 4
# ['MD']
# ['DO']
# ['MD']
# ['DC']
# 2
# 0
# 0
# 2
# ['MD']
# ['DDS']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD', 'PHD']
# 1
# 4
# ['OD']
# ['MD']
# ['DDS']
# ['MSW']
# 2
# 6
# ['DO']
# ['OD']
# ['MD']
# ['MD']
# ['MSW']
# ['ABOM']
# 2
# 10
# ['MD']
# ['RPH']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['CRNA']
# ['MD']
# 8
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['MD']
# ['RT', 'R', 'CT']
# ['MD']
# ['MD']
# ['OD']
# ['DPM']
# ['DMD']
# ['MD']
# ['MD']
# 6
# 10
# ['MD']
# ['MD']
# ['RT', 'R', 'CT']
# ['MD']
# ['MD']
# ['OD']
# ['DPM']
# ['DMD']
# ['MD']
# ['MD']
# 6
# 10
# ['CRNA']
# ['CRNA']
# ['RPH']
# ['MD']
# ['DC']
# ['MD']
# ['DO']
# ['MD']
# ['MD']
# ['DMD']
# 4
# 1
# ['MD']
# 1
# 1
# ['PHD']
# 1
# 10
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['MD']
# 10
# 1
# ['MD']
# 1
# 9
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PA', 'C']
# ['LCSW']
# ['MD']
# ['MD']
# ['MD']
# 7
# 2
# ['MD']
# ['MD']
# 2
# 3
# ['MD']
# 3
# 1
# ['MD']
# 1
# 10
# ['DC']
# ['PT']
# ['CRNA']
# ['MD']
# ['MD']
# ['CRNA']
# ['DO']
# ['MD']
# ['PT']
# ['MD']
# 4
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['MD']
# ['RPH', 'MBA']
# ['MD']
# ['PHARMD']
# ['DDS']
# ['MD']
# ['MD']
# ['DDS']
# ['DDS']
# 8
# 10
# ['MD']
# ['RDHAP']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 9
# 3
# ['MD']
# ['MD']
# 3
# 3
# ['MD']
# ['MD']
# ['MD']
# 3
# 3
# ['MD']
# ['MD']
# ['MD']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 3
# ['MD']
# ['DDS']
# ['MD']
# 3
# 3
# ['MD']
# ['MD']
# ['MD']
# 3
# 1
# ['MD', 'FACP', 'FACC']
# 1
# 4
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 4
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 5
# ['MD']
# ['MD']
# ['MD']
# ['AUD']
# ['PHARMD']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['PAC']
# 0
# 1
# ['MD']
# 1
# 9
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DC']
# ['MD']
# ['MD']
# ['LDO']
# 7
# 7
# ['DDS']
# ['MD']
# ['DC']
# ['MD']
# ['MD']
# ['PHD']
# 6
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 7
# ['MSPT']
# ['MD']
# ['DDS']
# ['MD']
# ['MA', 'LAMFT']
# 5
# 6
# ['MD']
# ['MS', 'LAC']
# ['MD', 'FACC', 'FACP']
# ['DDS']
# ['MA', 'LMFT']
# ['LICSW']
# 3
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 3
# ['DC']
# ['MD']
# ['DMD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# ['OD']
# 1
# 10
# ['MD']
# ['PHYSICAL', 'THERAPIST']
# ['DMD']
# ['MD']
# ['MD']
# ['PA']
# ['PT']
# ['PHD']
# ['DDS']
# 6
# 10
# ['MD']
# ['MD']
# ['MD']
# ['DMD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 9
# 10
# ['DC']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# 9
# 10
# ['MD']
# ['MD']
# ['MD']
# ['RPH', 'CDE']
# ['MD']
# ['MD']
# ['MD']
# ['M', 'D']
# ['MD']
# ['PA']
# 7
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['OD', 'PHD']
# ['MD']
# 2
# 2
# ['MD']
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['DO']
# ['MD']
# ['DO']
# ['PT']
# ['ATC']
# ['MD']
# ['LAC']
# ['DC']
# ['MSWCADC', 'I']
# ['DMD']
# 2
# 8
# ['DMD']
# ['DC']
# ['MD']
# ['DDS', 'MSPA']
# ['MD']
# ['PHD']
# ['PHD']
# 6
# 9
# ['DC']
# ['MD']
# ['MD']
# ['DDS']
# ['OD']
# ['DDS']
# ['DDS', 'MS']
# ['LPC']
# ['MD']
# 6
# 10
# ['MD']
# ['MD']
# ['PA']
# ['MD']
# ['MD']
# ['LCSW']
# ['DDS']
# ['DMD']
# ['MFT']
# 6
# 10
# ['MD']
# ['MD']
# ['PA']
# ['MD']
# ['MD']
# ['LCSW']
# ['DDS']
# ['DMD']
# ['MFT']
# 6
# 10
# ['PSYD']
# ['DDS']
# ['DDS']
# ['MD']
# ['MD']
# ['DDS', 'MS']
# ['DDS']
# ['CRNA']
# ['DC', 'DOCTOR', 'OF', 'CHIROPR']
# ['DDS']
# 7
# 10
# ['MD']
# ['MD']
# ['MD']
# ['OD', 'MS']
# ['MD']
# ['MD']
# ['PHD']
# ['MD']
# ['MD']
# ['MD']
# 9
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 5
# ['MD']
# ['MD']
# ['MD']
# 5
# 3
# ['MD']
# ['MD']
# ['DO']
# 2
# 1
# ['MD']
# 1
# 1
# ['MEDICAL', 'DOCTOR']
# 0
# 1
# ['OD']
# 0
# 2
# ['MD']
# ['MD']
# 2
# 5
# ['MD']
# ['MD']
# ['MD']
# ['DMD']
# ['PT', 'DPT']
# 3
# 7
# ['MD']
# ['MD']
# ['DPM']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# 6
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 9
# ['DO']
# ['MA', 'LPC']
# ['DPM']
# ['PAAA']
# ['PHARMD']
# ['PT']
# 3
# 9
# ['DO']
# ['MA', 'LPC']
# ['DPM']
# ['PAAA']
# ['PHARMD']
# ['PT']
# 3
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD', 'MPH']
# ['MD']
# ['MD']
# ['MD']
# ['LPCIT']
# ['LCSW']
# 8
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PAC']
# 9
# 10
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['PAC']
# 9
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['DDS']
# ['MD', 'PHD']
# 2
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD', 'PHD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['LAC', 'OMD', 'PHARM']
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD', 'PHD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 10
# ['DPM']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['MD']
# ['DDS']
# ['AUD']
# 8
# 9
# ['PT']
# ['MD']
# ['MD']
# ['DMD']
# ['OD']
# ['DDS']
# ['DC']
# ['MS', 'NCC', 'PLPC']
# 4
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 6
# ['MD']
# ['MD']
# ['DDS']
# ['MD']
# ['LMSW']
# ['DPT']
# 4
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1
# 2
# ['MD']
# 2
# 1
# ['MD']
# 1
# 1
# ['DMD']
# 0
# 1
# ['MD']
# 1
# 1
# ['MD']
# 1

# %%
npi_res[0]
# Out:
# (3497.0,
#  'ROY KENNETH AARON',
#  (1,
#   [{u'addresses': [{u'address_1': u'100 BUTLER DR',
#       u'address_2': u'',
#       u'address_purpose': u'LOCATION',
#       u'address_type': u'DOM',
#       u'city': u'PROVIDENCE',
#       u'country_code': u'US',
#       u'country_name': u'United States',
#       u'postal_code': u'029064862',
#       u'state': u'RI',
#       u'telephone_number': u'401-274-9660'},
#      {u'address_1': u'PO BOX 1119',
#       u'address_2': u'',
#       u'address_purpose': u'MAILING',
#       u'address_type': u'DOM',
#       u'city': u'PROVIDENCE',
#       u'country_code': u'US',
#       u'country_name': u'United States',
#       u'postal_code': u'029011119',
#       u'state': u'RI',
#       u'telephone_number': u'401-274-9660'}],
#     u'basic': {u'credential': u'M.D.',
#      u'enumeration_date': u'2006-06-07',
#      u'first_name': u'ROY',
#      u'gender': u'M',
#      u'last_name': u'AARON',
#      u'last_updated': u'2014-08-25',
#      u'middle_name': u'KENNETH',
#      u'name': u'AARON ROY',
#      u'sole_proprietor': u'YES',
#      u'status': u'A'},
#     u'created_epoch': 1149638400,
#     u'enumeration_type': u'NPI-1',
#     u'identifiers': [{u'code': u'02',
#       u'desc': u'MEDICARE UPIN',
#       u'identifier': u'B98872',
#       u'issuer': u'',
#       u'state': u''},
#      {u'code': u'04',
#       u'desc': u'MEDICARE ID-Type Unspecified',
#       u'identifier': u'007006564',
#       u'issuer': u'',
#       u'state': u'RI'}],
#     u'last_updated_epoch': 1408924800,
#     u'number': 1336189661,
#     u'other_names': [],
#     u'taxonomies': [{u'code': u'207X00000X',
#       u'desc': u'Orthopaedic Surgery',
#       u'license': u'05878',
#       u'primary': True,
#       u'state': u'RI'}]}]))

# %%
no_npi = filter(lambda x: x[2][0]==0, npi_res) 
one_npi = filter(lambda x: x[2][0]==1, npi_res) 
multiple_npi = filter(lambda x: x[2][0]>1, npi_res)

# %%
one_npi_numbers = {x[0]: x[2][1][0]['number'] for x in one_npi}
multiple_npi_numbers = {x[0]: map(lambda y: y['number'], x[2][1]) for x in multiple_npi}

# %%
one_npi_numbers[1]
# Out:
# 1801850656

# %%
df['NPI'] = np.nan

# %%
' | '.join(['asd'])
# Out:
# 'asd'

# %%
def get_npi_number(person_uuid):
    npi = one_npi_numbers.get(person_uuid, None)
    if not npi:
        npi = multiple_npi_numbers.get(person_uuid, None)
    if not npi:
        return np.nan
    if isinstance(npi, list):
        return ' | '.join(map(str, npi))
    return str(npi)

def get_num_npi_res(npi_str):
    if pd.isnull(npi_str):
        return 0
    return len(npi_str.split(' | '))

# %%
df['NPI'] = df.person_uuid.apply(get_npi_number)
df['number_NPI_results'] = df.NPI.apply(get_num_npi_res)

# %%
df.head()
# Out:
#    dno  person_uuid  application_year_min  application_year_max  eod_year  \
# 0  1.0       3497.0                1970.0                1970.0    1972.0
# 1  2.0       3743.0                1966.0                1966.0    1967.0
# 2  3.0       4127.0                1965.0                1965.0    1965.0
# 3  NaN       2243.0                1971.0                1971.0       NaN
# 4  5.0       1418.0                1962.0                1962.0    1964.0
#
#   clean_first_name clean_middle_name clean_last_name  control_flag  \
# 0              ROY           KENNETH           AARON             0
# 1           STUART              ALAN        AARONSON             0
# 2              JON            MORTON            AASE             0
# 3           LELAND           RUSSELL           ABBEY             1
# 4           HOWARD                 R            ABEL             0
#
#    time_period_flag         ...          supervisor  teaching to_drop  \
# 0                 1         ...                 NaN       1.0   False
# 1                 1         ...          Stephenson       1.0   False
# 2                 1         ...                 NaN       NaN   False
# 3                 1         ...                 NaN       1.0   False
# 4                 0         ...              Bailar       0.0   False
#
#   undergrad_year_grad undergraduate_school withdrawal year_grad  zip_code  \
# 0                 NaN                  NaN       -9.0    1969.0     11694
# 1                 NaN                  NaN       -9.0    1966.0       NaN
# 2                 NaN                  NaN       -9.0       NaN       NaN
# 3                 NaN                  NaN        0.0       NaN       NaN
# 4                 NaN                  NaN       -9.0    1962.0       NaN
#
#           NPI  number_NPI_results
# 0  1336189661                   1
# 1  1336513100                   1
# 2  1790744316                   1
# 3  1801906383                   1
# 4  1750496568                   1
#
# [5 rows x 107 columns]

# %%
df.to_csv(os.path.join(APP_DATA_DIR, 'NPI_df.csv'))

# %%
df2 = df[NAME_COLS + ['medical_school', 'medschool_year_grad', 'control_flag', 'time_period_flag', 'person_uuid', 
    'dno', 'is_female', 'is_foreign', 'eod_year', 'application_year_max']]

# %%
df2.to_csv(os.path.join(APP_DATA_DIR, 'NPI_info.csv'), index=False)

# %%
print len(no_npi)
print len(one_npi)
print len(multiple_npi)
# Out:
# 1168
# 1949
# 500

# %%
res = search('Jacob', 'ackerman')

parse_results(res, 'lewis')
# Out:
# 1
# 1
# middle
# {u'addresses': [{u'city': u'BROOKLYN', u'address_2': u'', u'telephone_number': u'718-968-8700', u'fax_number': u'718-968-8743', u'state': u'NY', u'postal_code': u'11234', u'address_1': u'1901 UTICA AVE', u'country_code': u'US', u'country_name': u'United States', u'address_type': u'DOM', u'address_purpose': u'LOCATION'}, {u'city': u'BROOKLYN', u'address_2': u'', u'telephone_number': u'718-968-8700', u'fax_number': u'718-968-8743', u'state': u'NY', u'postal_code': u'11234', u'address_1': u'1901 UTICA AVE', u'country_code': u'US', u'country_name': u'United States', u'address_type': u'DOM', u'address_purpose': u'MAILING'}], u'created_epoch': 1158278400, u'identifiers': [{u'issuer': u'NHIC', u'state': u'NY', u'code': u'01', u'identifier': u'0147830001', u'desc': u'Other'}, {u'issuer': u'', u'state': u'NY', u'code': u'04', u'identifier': u'5770100', u'desc': u'MEDICARE ID-Type Unspecified'}, {u'issuer': u'RAILROAD MEDICARE', u'state': u'NY', u'code': u'01', u'identifier': u'180029308', u'desc': u'Other'}, {u'issuer': u'', u'state': u'NY', u'code': u'02', u'identifier': u'B78015', u'desc': u'MEDICARE UPIN'}, {u'issuer': u'', u'state': u'NY', u'code': u'05', u'identifier': u'00203892', u'desc': u'MEDICAID'}], u'other_names': [], u'number': 1710083050, u'last_updated_epoch': 1333411200, u'basic': {u'status': u'A', u'credential': u'MD', u'first_name': u'JACOB', u'last_name': u'ACKERMAN', u'last_updated': u'2012-04-03', u'name': u'ACKERMAN JACOB', u'gender': u'M', u'sole_proprietor': u'NO', u'middle_name': u'L', u'enumeration_date': u'2006-09-15'}, u'enumeration_type': u'NPI-1', u'taxonomies': [{u'state': u'NY', u'code': u'207W00000X', u'primary': True, u'license': u'112574', u'desc': u'Ophthalmology'}]}
# L
# L
# (1,
#  [{u'addresses': [{u'address_1': u'1901 UTICA AVE',
#      u'address_2': u'',
#      u'address_purpose': u'LOCATION',
#      u'address_type': u'DOM',
#      u'city': u'BROOKLYN',
#      u'country_code': u'US',
#      u'country_name': u'United States',
#      u'fax_number': u'718-968-8743',
#      u'postal_code': u'11234',
#      u'state': u'NY',
#      u'telephone_number': u'718-968-8700'},
#     {u'address_1': u'1901 UTICA AVE',
#      u'address_2': u'',
#      u'address_purpose': u'MAILING',
#      u'address_type': u'DOM',
#      u'city': u'BROOKLYN',
#      u'country_code': u'US',
#      u'country_name': u'United States',
#      u'fax_number': u'718-968-8743',
#      u'postal_code': u'11234',
#      u'state': u'NY',
#      u'telephone_number': u'718-968-8700'}],
#    u'basic': {u'credential': u'MD',
#     u'enumeration_date': u'2006-09-15',
#     u'first_name': u'JACOB',
#     u'gender': u'M',
#     u'last_name': u'ACKERMAN',
#     u'last_updated': u'2012-04-03',
#     u'middle_name': u'L',
#     u'name': u'ACKERMAN JACOB',
#     u'sole_proprietor': u'NO',
#     u'status': u'A'},
#    u'created_epoch': 1158278400,
#    u'enumeration_type': u'NPI-1',
#    u'identifiers': [{u'code': u'01',
#      u'desc': u'Other',
#      u'identifier': u'0147830001',
#      u'issuer': u'NHIC',
#      u'state': u'NY'},
#     {u'code': u'04',
#      u'desc': u'MEDICARE ID-Type Unspecified',
#      u'identifier': u'5770100',
#      u'issuer': u'',
#      u'state': u'NY'},
#     {u'code': u'01',
#      u'desc': u'Other',
#      u'identifier': u'180029308',
#      u'issuer': u'RAILROAD MEDICARE',
#      u'state': u'NY'},
#     {u'code': u'02',
#      u'desc': u'MEDICARE UPIN',
#      u'identifier': u'B78015',
#      u'issuer': u'',
#      u'state': u'NY'},
#     {u'code': u'05',
#      u'desc': u'MEDICAID',
#      u'identifier': u'00203892',
#      u'issuer': u'',
#      u'state': u'NY'}],
#    u'last_updated_epoch': 1333411200,
#    u'number': 1710083050,
#    u'other_names': [],
#    u'taxonomies': [{u'code': u'207W00000X',
#      u'desc': u'Ophthalmology',
#      u'license': u'112574',
#      u'primary': True,
#      u'state': u'NY'}]}])

# %%
res
# Out:
# {u'result_count': 1,
#  u'results': [{u'addresses': [{u'address_1': u'1901 UTICA AVE',
#      u'address_2': u'',
#      u'address_purpose': u'LOCATION',
#      u'address_type': u'DOM',
#      u'city': u'BROOKLYN',
#      u'country_code': u'US',
#      u'country_name': u'United States',
#      u'fax_number': u'718-968-8743',
#      u'postal_code': u'11234',
#      u'state': u'NY',
#      u'telephone_number': u'718-968-8700'},
#     {u'address_1': u'1901 UTICA AVE',
#      u'address_2': u'',
#      u'address_purpose': u'MAILING',
#      u'address_type': u'DOM',
#      u'city': u'BROOKLYN',
#      u'country_code': u'US',
#      u'country_name': u'United States',
#      u'fax_number': u'718-968-8743',
#      u'postal_code': u'11234',
#      u'state': u'NY',
#      u'telephone_number': u'718-968-8700'}],
#    u'basic': {u'credential': u'MD',
#     u'enumeration_date': u'2006-09-15',
#     u'first_name': u'JACOB',
#     u'gender': u'M',
#     u'last_name': u'ACKERMAN',
#     u'last_updated': u'2012-04-03',
#     u'middle_name': u'L',
#     u'name': u'ACKERMAN JACOB',
#     u'sole_proprietor': u'NO',
#     u'status': u'A'},
#    u'created_epoch': 1158278400,
#    u'enumeration_type': u'NPI-1',
#    u'identifiers': [{u'code': u'01',
#      u'desc': u'Other',
#      u'identifier': u'0147830001',
#      u'issuer': u'NHIC',
#      u'state': u'NY'},
#     {u'code': u'04',
#      u'desc': u'MEDICARE ID-Type Unspecified',
#      u'identifier': u'5770100',
#      u'issuer': u'',
#      u'state': u'NY'},
#     {u'code': u'01',
#      u'desc': u'Other',
#      u'identifier': u'180029308',
#      u'issuer': u'RAILROAD MEDICARE',
#      u'state': u'NY'},
#     {u'code': u'02',
#      u'desc': u'MEDICARE UPIN',
#      u'identifier': u'B78015',
#      u'issuer': u'',
#      u'state': u'NY'},
#     {u'code': u'05',
#      u'desc': u'MEDICAID',
#      u'identifier': u'00203892',
#      u'issuer': u'',
#      u'state': u'NY'}],
#    u'last_updated_epoch': 1333411200,
#    u'number': 1710083050,
#    u'other_names': [],
#    u'taxonomies': [{u'code': u'207W00000X',
#      u'desc': u'Ophthalmology',
#      u'license': u'112574',
#      u'primary': True,
#      u'state': u'NY'}]}]}

# %%
df.head(20)
# Out:
#      dno  person_uuid  application_year_min  application_year_max  eod_year  \
# 0    1.0       3497.0                1970.0                1970.0    1972.0
# 1    2.0       3743.0                1966.0                1966.0    1967.0
# 2    3.0       4127.0                1965.0                1965.0    1965.0
# 3    NaN       2243.0                1971.0                1971.0       NaN
# 4    5.0       1418.0                1962.0                1962.0    1964.0
# 5    6.0       3466.0                1966.0                1966.0    1968.0
# 6    8.0       2423.0                1966.0                1966.0    1967.0
# 7    9.0       1366.0                1966.0                1966.0    1967.0
# 8    NaN       3181.0                1970.0                1970.0       NaN
# 9   10.0       3715.0                1967.0                1967.0    1971.0
# 10  11.0        141.0                1969.0                1969.0    1971.0
# 11   NaN       2213.0                1972.0                1972.0       NaN
# 12  13.0       3490.0                1974.0                1974.0    1976.0
# 13  15.0       1455.0                1966.0                1966.0    1968.0
# 14   NaN       1481.0                1971.0                1971.0       NaN
# 15  16.0       1543.0                1962.0                1962.0    1962.0
# 16   NaN        463.0                1971.0                1971.0       NaN
# 17  17.0       2726.0                1973.0                1973.0    1975.0
# 18  20.0       2659.0                1962.0                1962.0    1965.0
# 19  21.0       4033.0                1971.0                1971.0    1973.0
#
#    clean_first_name clean_middle_name clean_last_name  control_flag  \
# 0               ROY           KENNETH           AARON             0
# 1            STUART              ALAN        AARONSON             0
# 2               JON            MORTON            AASE             0
# 3            LELAND           RUSSELL           ABBEY             1
# 4            HOWARD                 R            ABEL             0
# 5            RONALD                 M            ABEL             0
# 6            MARTIN             DAVID         ABELOFF             0
# 7           HERBERT                 T         ABELSON             0
# 8            ROBERT             CLARK            ABER             0
# 9            STEVEN             LURIA           ABLON             0
# 10            AMNON               ZVI      ABRAMOWITZ             0
# 11         LAWRENCE            MILTON          ABRAMS             1
# 12             ROSS             ALLEN          ABRAMS             0
# 13           ITAMAR           BEZALEL          ABRASS             0
# 14            JACOB             LEWIS        ACKERMAN             1
# 15            JAMES                 L        ACKERMAN             0
# 16          CHARLES           MICHAEL           ACTON             1
# 17           NORMAN            EUGENE           ADAIR             0
# 18           MORTON            SAMUEL           ADAMS             0
# 19          WILLIAM              PAUL           ADAMS             0
#
#     time_period_flag    ...    ssn           state  supervisor teaching  \
# 0                  1    ...    NaN        New York         NaN      1.0
# 1                  1    ...    NaN      California  Stephenson      1.0
# 2                  1    ...    NaN      Washington         NaN      NaN
# 3                  1    ...    NaN        New York         NaN      1.0
# 4                  0    ...    NaN        New York      Bailar      0.0
# 5                  1    ...    NaN        New York      Morrow      1.0
# 6                  1    ...    NaN    Pennsylvania       Block      0.0
# 7                  1    ...    NaN        Missouri      Dalton      1.0
# 8                  1    ...    NaN    Pennsylvania         NaN      1.0
# 9                  1    ...    NaN            Ohio         NaN      1.0
# 10                 1    ...    NaN        New York      Guroff      1.0
# 11                 1    ...    NaN          Kansas         NaN      1.0
# 12                 1    ...    NaN  North Carolina         NaN      1.0
# 13                 1    ...    NaN      California         NaN      1.0
# 14                 1    ...    NaN        New York         NaN      1.0
# 15                 0    ...    NaN      New Jersey         NaN      0.0
# 16                 1    ...    NaN         Indiana         NaN      1.0
# 17                 1    ...    NaN        Missouri     Adamson      0.0
# 18                 0    ...    NaN        New York      Witkop      1.0
# 19                 1    ...    NaN    Pennsylvania         NaN      1.0
#
#    to_drop undergrad_year_grad        undergraduate_school  withdrawal  \
# 0    False                 NaN                         NaN        -9.0
# 1    False                 NaN                         NaN        -9.0
# 2    False                 NaN                         NaN        -9.0
# 3    False                 NaN                         NaN         0.0
# 4    False                 NaN                         NaN        -9.0
# 5    False                 NaN                         NaN        -9.0
# 6    False                 NaN                         NaN        -9.0
# 7    False                 NaN                         NaN        -9.0
# 8    False                 NaN                         NaN        -9.0
# 9    False              1963.0             Amherst College        -9.0
# 10   False                 NaN                         NaN        -9.0
# 11   False                 NaN                         NaN         0.0
# 12   False              1969.0  University of Pennsylvania        -9.0
# 13   False                 NaN                         NaN        -9.0
# 14   False                 NaN                         NaN         0.0
# 15   False                 NaN                         NaN        -9.0
# 16   False              1965.0              Wabash College         0.0
# 17   False                 NaN                         NaN        -9.0
# 18   False                 NaN                         NaN        -9.0
# 19   False              1967.0           Dartmouth College        -9.0
#
#     year_grad  zip_code
# 0      1969.0   11694.0
# 1      1966.0       NaN
# 2         NaN       NaN
# 3         NaN       NaN
# 4      1962.0       NaN
# 5      1966.0       NaN
# 6      1966.0       NaN
# 7      1966.0   63132.0
# 8         NaN   18042.0
# 9      1967.0   44120.0
# 10     1969.0   10461.0
# 11        NaN       NaN
# 12     1973.0       NaN
# 13     1966.0   94131.0
# 14        NaN   10461.0
# 15     1960.0       NaN
# 16        NaN   46224.0
# 17     1973.0   64080.0
# 18     1962.0       NaN
# 19     1971.0   16142.0
#
# [20 rows x 105 columns]

# %%
search('stuart', 'aaronson')
# Out:
# {u'result_count': 1,
#  u'results': [{u'addresses': [{u'address_1': u'40 E 94TH ST APT 23B',
#      u'address_2': u'',
#      u'address_purpose': u'LOCATION',
#      u'address_type': u'DOM',
#      u'city': u'NEW YORK',
#      u'country_code': u'US',
#      u'country_name': u'United States',
#      u'fax_number': u'212-987-2240',
#      u'postal_code': u'101280738',
#      u'state': u'NY',
#      u'telephone_number': u'212-659-5400'},
#     {u'address_1': u'40 E 94TH ST APT 23B',
#      u'address_2': u'',
#      u'address_purpose': u'MAILING',
#      u'address_type': u'DOM',
#      u'city': u'NEW YORK',
#      u'country_code': u'US',
#      u'country_name': u'United States',
#      u'fax_number': u'212-987-2240',
#      u'postal_code': u'101280738',
#      u'state': u'NY',
#      u'telephone_number': u'212-659-5400'}],
#    u'basic': {u'credential': u'M.D.',
#     u'enumeration_date': u'2015-11-17',
#     u'first_name': u'STUART',
#     u'gender': u'M',
#     u'last_name': u'AARONSON',
#     u'last_updated': u'2015-11-17',
#     u'name': u'AARONSON STUART',
#     u'name_prefix': u'DR.',
#     u'sole_proprietor': u'YES',
#     u'status': u'A'},
#    u'created_epoch': 1447718400,
#    u'enumeration_type': u'NPI-1',
#    u'identifiers': [],
#    u'last_updated_epoch': 1447776841,
#    u'number': 1336513100,
#    u'other_names': [],
#    u'taxonomies': [{u'code': u'207Q00000X',
#      u'desc': u'Family Medicine',
#      u'license': u'NY109417',
#      u'primary': True,
#      u'state': u'NY'}]}]}
